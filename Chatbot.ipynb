# %%
import torch
from torch.jit import script, trace
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import csv
import random
import re
import os
import unicodedata
import codecs
from io import open
import itertools
import math
import json
import pandas as pd

# %%
 ! pip install -q kaggle

# %%
os.environ['KAGGLE_USERNAME'] = "" # username from the json file
os.environ['KAGGLE_KEY'] = "" # key from the json file
# !kaggle datasets download -d rtatman/ubuntu-dialogue-corpus
# Out:
# Downloading ubuntu-dialogue-corpus.zip to /content
# 100% 799M/799M [00:43<00:00, 20.2MB/s]
# 100% 799M/799M [00:43<00:00, 19.5MB/s]

# %%
! unzip ubuntu-dialogue-corpus.zip
# Out:
# Archive:  ubuntu-dialogue-corpus.zip
#   inflating: Ubuntu-dialogue-corpus/dialogueText.csv
#   inflating: Ubuntu-dialogue-corpus/dialogueText_196.csv
#   inflating: Ubuntu-dialogue-corpus/dialogueText_301.csv
#   inflating: toc.csv

# %%
text_df = pd.read_csv('Ubuntu-dialogue-corpus/dialogueText.csv')

# %%
text_df.head()
# Out:
#    folder  dialogueID                      date       from         to  \
# 0       3  126125.tsv  2008-04-23T14:55:00.000Z  bad_image        NaN
# 1       3  126125.tsv  2008-04-23T14:56:00.000Z  bad_image        NaN
# 2       3  126125.tsv  2008-04-23T14:57:00.000Z  lordleemo  bad_image
# 3       3   64545.tsv  2009-08-01T06:22:00.000Z   mechtech        NaN
# 4       3   64545.tsv  2009-08-01T06:22:00.000Z   mechtech        NaN
#
#                                                 text
# 0  Hello folks, please help me a bit with the fol...
# 1  Did I choose a bad channel? I ask because you ...
# 2  the second sentence is better english   and we...
# 3                                       Sock Puppe?t
# 4                                               WTF?

# %%
# Turn a Unicode string to plain ASCII, thanks to
# https://stackoverflow.com/a/518232/2809427
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

# Lowercase, trim, and remove non-letter characters
def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    s = re.sub(r"\s+", r" ", s).strip()
    return s

count = 0
sentence_pairs = []
with open('Ubuntu-dialogue-corpus/dialogueText.csv', newline='') as csvfile:
    dialogue = csv.reader(csvfile)
    question = ''
    answer = ''
    previous_frm = 'Na'
    previous_to = 'Na'
    for row in dialogue:
      count = count +1
      # skip the first row
      if count ==1:
        continue


      frm = row[3]
      to = row[4]
      text = row[5]

      #TODO this logic doesn't account for multiple answers to the samae question

      # if the text is to the previous from it's an answer
      if to == previous_frm:
        answer += f' {text}'
      # if the from and to are still the same it's the sam question
      elif frm == previous_frm and to == previous_to:
        question += f' {text}'
      # if the from or to are different we assume it's a new question
      elif frm != previous_frm or to != previous_to:
        # if the previous question got an answer add it
        norm_question = normalizeString(question)
        norm_answer = normalizeString(answer)
        if answer:
          sentence_pairs.append([norm_question, norm_answer])
        question = text
        answer = ''
      else:
        raise ValueError(f'unknown state: {frm} - {to} - {previous_frm} -- {previous_to}')

      previous_frm = frm
      previous_to = to

# %%
MAX_LENGTH = 20

# Returns True if both sentences in a pair 'p' are under the MAX_LENGTH threshold
def filterPair(p):
    # Input sequences need to preserve the last word for EOS token
    return len(p[0].split(' ')) < MAX_LENGTH and len(p[1].split(' ')) < MAX_LENGTH

# Filter pairs using the ``filterPair`` condition
def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

sentence_pairs_filtered = filterPairs(sentence_pairs)

# %%
print(f'count before filter{len(sentence_pairs)}')
print(f'count after filter{len(sentence_pairs_filtered)}')
for pair in sentence_pairs_filtered[:10]:
    print(sentence_pairs_filtered)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# Default word tokens
PAD_token = 0  # Used for padding short sentences
SOS_token = 1  # Start-of-sentence token
EOS_token = 2  # End-of-sentence token

class Voc:
    def __init__(self, name):
        self.name = name
        self.trimmed = False
        self.word2index = {}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
        self.num_words = 3  # Count SOS, EOS, PAD

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.num_words
            self.word2count[word] = 1
            self.index2word[self.num_words] = word
            self.num_words += 1
        else:
            self.word2count[word] += 1

    # Remove words below a certain count threshold
    def trim(self, min_count):
        if self.trimmed:
            return
        self.trimmed = True

        keep_words = []

        for k, v in self.word2count.items():
            if v >= min_count:
                keep_words.append(k)

        print('keep_words {} / {} = {:.4f}'.format(
            len(keep_words), len(self.word2index), len(keep_words) / len(self.word2index)
        ))

        # Reinitialize dictionaries
        self.word2index = {}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
        self.num_words = 3 # Count default tokens

        for word in keep_words:
            self.addWord(word)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
corpus_name = 'Ubuntu-dialogue-corpus'
voc = Voc(corpus_name)
for pair in sentence_pairs_filtered:
        voc.addSentence(pair[0])
        voc.addSentence(pair[1])


pairs = sentence_pairs_filtered

# %%
MIN_COUNT = 3    # Minimum word count threshold for trimming

def trimRareWords(voc, pairs, MIN_COUNT):
    # Trim words used under the MIN_COUNT from the voc
    voc.trim(MIN_COUNT)
    # Filter out pairs with trimmed words
    keep_pairs = []
    for pair in pairs:
        input_sentence = pair[0]
        output_sentence = pair[1]
        keep_input = True
        keep_output = True
        # Check input sentence
        for word in input_sentence.split(' '):
            if word not in voc.word2index:
                keep_input = False
                break
        # Check output sentence
        for word in output_sentence.split(' '):
            if word not in voc.word2index:
                keep_output = False
                break

        # Only keep pairs that do not contain trimmed word(s) in their input or output sentence
        if keep_input and keep_output:
            keep_pairs.append(pair)

    print("Trimmed from {} pairs to {}, {:.4f} of total".format(len(pairs), len(keep_pairs), len(keep_pairs) / len(pairs)))
    return keep_pairs


# Trim voc and pairs
pairs = trimRareWords(voc, pairs, MIN_COUNT)
# Out:
# keep_words 17834 / 62540 = 0.2852
# Trimmed from 139187 pairs to 99658, 0.7160 of total

# %%
def indexesFromSentence(voc, sentence):
    return [voc.word2index[word] for word in sentence.split(' ')] + [EOS_token]


def zeroPadding(l, fillvalue=PAD_token):
    return list(itertools.zip_longest(*l, fillvalue=fillvalue))

def binaryMatrix(l, value=PAD_token):
    m = []
    for i, seq in enumerate(l):
        m.append([])
        for token in seq:
            if token == PAD_token:
                m[i].append(0)
            else:
                m[i].append(1)
    return m

# Returns padded input sequence tensor and lengths
def inputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    padList = zeroPadding(indexes_batch)
    padVar = torch.LongTensor(padList)
    return padVar, lengths

# Returns padded target sequence tensor, padding mask, and max target length
def outputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    max_target_len = max([len(indexes) for indexes in indexes_batch])
    padList = zeroPadding(indexes_batch)
    mask = binaryMatrix(padList)
    mask = torch.BoolTensor(mask)
    padVar = torch.LongTensor(padList)
    return padVar, mask, max_target_len

# Returns all items for a given batch of pairs
def batch2TrainData(voc, pair_batch):
    pair_batch.sort(key=lambda x: len(x[0].split(" ")), reverse=True)
    input_batch, output_batch = [], []
    for pair in pair_batch:
        input_batch.append(pair[0])
        output_batch.append(pair[1])
    inp, lengths = inputVar(input_batch, voc)
    output, mask, max_target_len = outputVar(output_batch, voc)
    return inp, lengths, output, mask, max_target_len


# Example for validation
small_batch_size = 5
batches = batch2TrainData(voc, [random.choice(pairs) for _ in range(small_batch_size)])
input_variable, lengths, target_variable, mask, max_target_len = batches

print("input_variable:", input_variable)
print("lengths:", lengths)
print("target_variable:", target_variable)
print("mask:", mask)
print("max_target_len:", max_target_len)
# Out:
# input_variable: tensor([[ 295,   14,   23,  241, 6716],
#         [  23,   12,   45,  553, 3232],
#         [ 241,  221,   44,   98,   12],
#         [  38,   47,   93,  117,    2],
#         [ 284,   88,   47,  118,    0],
#         [ 588,  892, 1316,  239,    0],
#         [  31,    6, 1463, 1514,    0],
#         [ 137,  412,    6,    2,    0],
#         [ 829,  536,    2,    0,    0],
#         [  27, 2972,    0,    0,    0],
#         [  42,  151,    0,    0,    0],
#         [1299,  791,    0,    0,    0],
#         [ 173,    2,    0,    0,    0],
#         [ 174,    0,    0,    0,    0],
#         [   6,    0,    0,    0,    0],
#         [ 317,    0,    0,    0,    0],
#         [ 730,    0,    0,    0,    0],
#         [ 730,    0,    0,    0,    0],
#         [   2,    0,    0,    0,    0]])
# lengths: tensor([19, 13,  9,  8,  4])
# target_variable: tensor([[ 131, 2511,   38,  103,  179],
#         [ 277,    7,  376,  622,  390],
#         [1821,    8, 2519,  118,  391],
#         [   2,  104,   16,    7, 1508],
#         [   0,   47,  322,    6,   63],
#         [   0, 1667, 2519,  856,   76],
#         [   0,    9,   44, 4264,  112],
#         [   0, 1010,    6,   48,   99],
#         [   0,  356,    2,    6,   79],
#         [   0,  288,    0,    2,   47],
#         [   0,   20,    0,    0,  112],
#         [   0, 1026,    0,    0,  390],
#         [   0,  328,    0,    0,  391],
#         [   0, 2839,    0,    0,   63],
#         [   0,    8,    0,    0,  660],
#         [   0, 1069,    0,    0,  298],
#         [   0, 2296,    0,    0, 1509],
#         [   0,    2,    0,    0,   12],
#         [   0,    0,    0,    0,    2]])
# mask: tensor([[ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True],
#         [False,  True,  True,  True,  True],
#         [False,  True,  True,  True,  True],
#         [False,  True,  True,  True,  True],
#         [False,  True,  True,  True,  True],
#         [False,  True,  True,  True,  True],
#         [False,  True, False,  True,  True],
#         [False,  True, False, False,  True],
#         [False,  True, False, False,  True],
#         [False,  True, False, False,  True],
#         [False,  True, False, False,  True],
#         [False,  True, False, False,  True],
#         [False,  True, False, False,  True],
#         [False,  True, False, False,  True],
#         [False,  True, False, False,  True],
#         [False, False, False, False,  True]])
# max_target_len: 19

# %%
class EncoderRNN(nn.Module):
    def __init__(self, hidden_size, embedding, n_layers=1, dropout=0):
        super(EncoderRNN, self).__init__()
        self.n_layers = n_layers
        self.hidden_size = hidden_size
        self.embedding = embedding

        # Initialize GRU; the input_size and hidden_size parameters are both set to 'hidden_size'
        #   because our input size is a word embedding with number of features == hidden_size
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers,
                          dropout=(0 if n_layers == 1 else dropout), bidirectional=True)

    def forward(self, input_seq, input_lengths, hidden=None):
        # Convert word indexes to embeddings
        embedded = self.embedding(input_seq)
        # Pack padded batch of sequences for RNN module
        packed = nn.utils.rnn.pack_padded_sequence(embedded, input_lengths)
        # Forward pass through GRU
        outputs, hidden = self.gru(packed, hidden)
        # Unpack padding
        outputs, _ = nn.utils.rnn.pad_packed_sequence(outputs)
        # Sum bidirectional GRU outputs
        outputs = outputs[:, :, :self.hidden_size] + outputs[:, : ,self.hidden_size:]
        # Return output and final hidden state
        return outputs, hidden

# %%
# Luong attention layer
class Attn(nn.Module):
    def __init__(self, method, hidden_size):
        super(Attn, self).__init__()
        self.method = method
        if self.method not in ['dot', 'general', 'concat']:
            raise ValueError(self.method, "is not an appropriate attention method.")
        self.hidden_size = hidden_size
        if self.method == 'general':
            self.attn = nn.Linear(self.hidden_size, hidden_size)
        elif self.method == 'concat':
            self.attn = nn.Linear(self.hidden_size * 2, hidden_size)
            self.v = nn.Parameter(torch.FloatTensor(hidden_size))

    def dot_score(self, hidden, encoder_output):
        return torch.sum(hidden * encoder_output, dim=2)

    def general_score(self, hidden, encoder_output):
        energy = self.attn(encoder_output)
        return torch.sum(hidden * energy, dim=2)

    def concat_score(self, hidden, encoder_output):
        energy = self.attn(torch.cat((hidden.expand(encoder_output.size(0), -1, -1), encoder_output), 2)).tanh()
        return torch.sum(self.v * energy, dim=2)

    def forward(self, hidden, encoder_outputs):
        # Calculate the attention weights (energies) based on the given method
        if self.method == 'general':
            attn_energies = self.general_score(hidden, encoder_outputs)
        elif self.method == 'concat':
            attn_energies = self.concat_score(hidden, encoder_outputs)
        elif self.method == 'dot':
            attn_energies = self.dot_score(hidden, encoder_outputs)

        # Transpose max_length and batch_size dimensions
        attn_energies = attn_energies.t()

        # Return the softmax normalized probability scores (with added dimension)
        return F.softmax(attn_energies, dim=1).unsqueeze(1)

# %%
class LuongAttnDecoderRNN(nn.Module):
    def __init__(self, attn_model, embedding, hidden_size, output_size, n_layers=1, dropout=0.1):
        super(LuongAttnDecoderRNN, self).__init__()

        # Keep for reference
        self.attn_model = attn_model
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.n_layers = n_layers
        self.dropout = dropout

        # Define layers
        self.embedding = embedding
        self.embedding_dropout = nn.Dropout(dropout)
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers, dropout=(0 if n_layers == 1 else dropout))
        self.concat = nn.Linear(hidden_size * 2, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)

        self.attn = Attn(attn_model, hidden_size)

    def forward(self, input_step, last_hidden, encoder_outputs):
        # Note: we run this one step (word) at a time
        # Get embedding of current input word
        embedded = self.embedding(input_step)
        embedded = self.embedding_dropout(embedded)
        # Forward through unidirectional GRU
        rnn_output, hidden = self.gru(embedded, last_hidden)
        # Calculate attention weights from the current GRU output
        attn_weights = self.attn(rnn_output, encoder_outputs)
        # Multiply attention weights to encoder outputs to get new "weighted sum" context vector
        context = attn_weights.bmm(encoder_outputs.transpose(0, 1))
        # Concatenate weighted context vector and GRU output using Luong eq. 5
        rnn_output = rnn_output.squeeze(0)
        context = context.squeeze(1)
        concat_input = torch.cat((rnn_output, context), 1)
        concat_output = torch.tanh(self.concat(concat_input))
        # Predict next word using Luong eq. 6
        output = self.out(concat_output)
        output = F.softmax(output, dim=1)
        # Return output and final hidden state
        return output, hidden

# %%
def maskNLLLoss(inp, target, mask):
    nTotal = mask.sum()
    crossEntropy = -torch.log(torch.gather(inp, 1, target.view(-1, 1)).squeeze(1))
    loss = crossEntropy.masked_select(mask).mean()
    loss = loss.to(device)
    return loss, nTotal.item()

# %%
def train(input_variable, lengths, target_variable, mask, max_target_len, encoder, decoder, embedding,
          encoder_optimizer, decoder_optimizer, batch_size, clip, max_length=MAX_LENGTH):

    # Zero gradients
    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    # Set device options
    input_variable = input_variable.to(device)
    target_variable = target_variable.to(device)
    mask = mask.to(device)
    # Lengths for RNN packing should always be on the CPU
    lengths = lengths.to("cpu")

    # Initialize variables
    loss = 0
    print_losses = []
    n_totals = 0

    # Forward pass through encoder
    encoder_outputs, encoder_hidden = encoder(input_variable, lengths)

    # Create initial decoder input (start with SOS tokens for each sentence)
    decoder_input = torch.LongTensor([[SOS_token for _ in range(batch_size)]])
    decoder_input = decoder_input.to(device)

    # Set initial decoder hidden state to the encoder's final hidden state
    decoder_hidden = encoder_hidden[:decoder.n_layers]

    # Determine if we are using teacher forcing this iteration
    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    # Forward batch of sequences through decoder one time step at a time
    if use_teacher_forcing:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            # Teacher forcing: next input is current target
            decoder_input = target_variable[t].view(1, -1)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal
    else:
        for t in range(max_target_len):
            decoder_output, decoder_hidden = decoder(
                decoder_input, decoder_hidden, encoder_outputs
            )
            # No teacher forcing: next input is decoder's own current output
            _, topi = decoder_output.topk(1)
            decoder_input = torch.LongTensor([[topi[i][0] for i in range(batch_size)]])
            decoder_input = decoder_input.to(device)
            # Calculate and accumulate loss
            mask_loss, nTotal = maskNLLLoss(decoder_output, target_variable[t], mask[t])
            loss += mask_loss
            print_losses.append(mask_loss.item() * nTotal)
            n_totals += nTotal

    # Perform backpropagation
    loss.backward()

    # Clip gradients: gradients are modified in place
    _ = nn.utils.clip_grad_norm_(encoder.parameters(), clip)
    _ = nn.utils.clip_grad_norm_(decoder.parameters(), clip)

    # Adjust model weights
    encoder_optimizer.step()
    decoder_optimizer.step()

    return sum(print_losses) / n_totals

# %%
def trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer, embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size, print_every, save_every, clip, corpus_name, loadFilename):

    # Load batches for each iteration
    training_batches = [batch2TrainData(voc, [random.choice(pairs) for _ in range(batch_size)])
                      for _ in range(n_iteration)]

    # Initializations
    print('Initializing ...')
    start_iteration = 1
    print_loss = 0
    if loadFilename and os.path.isfile(loadFilename):
        start_iteration = checkpoint['iteration'] + 1

    # Training loop
    print("Training...")
    for iteration in range(start_iteration, n_iteration + 1):
        training_batch = training_batches[iteration - 1]
        # Extract fields from batch
        input_variable, lengths, target_variable, mask, max_target_len = training_batch

        # Run a training iteration with batch
        loss = train(input_variable, lengths, target_variable, mask, max_target_len, encoder,
                     decoder, embedding, encoder_optimizer, decoder_optimizer, batch_size, clip)
        print_loss += loss

        # Print progress
        if iteration % print_every == 0:
            print_loss_avg = print_loss / print_every
            print("Iteration: {}; Percent complete: {:.1f}%; Average loss: {:.4f}".format(iteration, iteration / n_iteration * 100, print_loss_avg))
            print_loss = 0

        # Save checkpoint
        if (iteration % save_every == 0):
            directory = os.path.join(save_dir, model_name, corpus_name, '{}-{}_{}'.format(encoder_n_layers, decoder_n_layers, hidden_size))
            if not os.path.exists(directory):
                os.makedirs(directory)
            torch.save({
                'iteration': iteration,
                'en': encoder.state_dict(),
                'de': decoder.state_dict(),
                'en_opt': encoder_optimizer.state_dict(),
                'de_opt': decoder_optimizer.state_dict(),
                'loss': loss,
                'voc_dict': voc.__dict__,
                'embedding': embedding.state_dict()
            }, os.path.join(directory, '{}_{}.tar'.format(iteration, 'checkpoint')))

# %%
class GreedySearchDecoder(nn.Module):
    def __init__(self, encoder, decoder):
        super(GreedySearchDecoder, self).__init__()
        self.encoder = encoder
        self.decoder = decoder

    def forward(self, input_seq, input_length, max_length):
        # Forward input through encoder model
        encoder_outputs, encoder_hidden = self.encoder(input_seq, input_length)
        # Prepare encoder's final hidden layer to be first hidden input to the decoder
        decoder_hidden = encoder_hidden[:decoder.n_layers]
        # Initialize decoder input with SOS_token
        decoder_input = torch.ones(1, 1, device=device, dtype=torch.long) * SOS_token
        # Initialize tensors to append decoded words to
        all_tokens = torch.zeros([0], device=device, dtype=torch.long)
        all_scores = torch.zeros([0], device=device)
        # Iteratively decode one word token at a time
        for _ in range(max_length):
            # Forward pass through decoder
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden, encoder_outputs)
            # Obtain most likely word token and its softmax score
            decoder_scores, decoder_input = torch.max(decoder_output, dim=1)
            # Record token and score
            all_tokens = torch.cat((all_tokens, decoder_input), dim=0)
            all_scores = torch.cat((all_scores, decoder_scores), dim=0)
            # Prepare current token to be next decoder input (add a dimension)
            decoder_input = torch.unsqueeze(decoder_input, 0)
        # Return collections of word tokens and scores
        return all_tokens, all_scores

# %%
def evaluate(encoder, decoder, searcher, voc, sentence, max_length=MAX_LENGTH):
    ### Format input sentence as a batch
    # words -> indexes
    indexes_batch = [indexesFromSentence(voc, sentence)]
    # Create lengths tensor
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    # Transpose dimensions of batch to match models' expectations
    input_batch = torch.LongTensor(indexes_batch).transpose(0, 1)
    # Use appropriate device
    input_batch = input_batch.to(device)
    lengths = lengths.to("cpu")
    # Decode sentence with searcher
    tokens, scores = searcher(input_batch, lengths, max_length)
    # indexes -> words
    decoded_words = [voc.index2word[token.item()] for token in tokens]
    return decoded_words


def evaluateInput(encoder, decoder, searcher, voc):
    input_sentence = ''
    while(1):
        try:
            # Get input sentence
            input_sentence = input('> ')
            # Check if it is quit case
            if input_sentence == 'q' or input_sentence == 'quit': break
            # Normalize sentence
            input_sentence = normalizeString(input_sentence)
            # Evaluate sentence
            output_words = evaluate(encoder, decoder, searcher, voc, input_sentence)
            # Format and print response sentence
            output_words[:] = [x for x in output_words if not (x == 'EOS' or x == 'PAD')]
            print('Bot:', ' '.join(output_words))

        except KeyError:
            print("Error: Encountered unknown word.")

# %%
# Configure models
model_name = 'cb_model'
attn_model = 'dot'
#``attn_model = 'general'``
#``attn_model = 'concat'``
hidden_size = 500
encoder_n_layers = 2
decoder_n_layers = 2
dropout = 0.1
batch_size = 64

# Set checkpoint to load from; set to None if starting from scratch
save_dir = '.'
loadFilename = None
checkpoint_iter = 4000

# %%
loadFilename = os.path.join(save_dir, model_name, corpus_name,
                    '{}-{}_{}'.format(encoder_n_layers, decoder_n_layers, hidden_size),
                    '{}_checkpoint.tar'.format(checkpoint_iter))

# %%
device = torch.device("cuda")
# Load model if a ``loadFilename`` is provided
if loadFilename and os.path.isfile(loadFilename):
    # If loading on same machine the model was trained on
    checkpoint = torch.load(loadFilename)
    # If loading a model trained on GPU to CPU
    #checkpoint = torch.load(loadFilename, map_location=torch.device('cpu'))
    encoder_sd = checkpoint['en']
    decoder_sd = checkpoint['de']
    encoder_optimizer_sd = checkpoint['en_opt']
    decoder_optimizer_sd = checkpoint['de_opt']
    embedding_sd = checkpoint['embedding']
    voc.__dict__ = checkpoint['voc_dict']


print('Building encoder and decoder ...')
# Initialize word embeddings
embedding = nn.Embedding(voc.num_words, hidden_size)
if loadFilename and os.path.isfile(loadFilename):
    embedding.load_state_dict(embedding_sd)
# Initialize encoder & decoder models
encoder = EncoderRNN(hidden_size, embedding, encoder_n_layers, dropout)
decoder = LuongAttnDecoderRNN(attn_model, embedding, hidden_size, voc.num_words, decoder_n_layers, dropout)
if loadFilename and os.path.isfile(loadFilename):
    encoder.load_state_dict(encoder_sd)
    decoder.load_state_dict(decoder_sd)
# Use appropriate device
encoder = encoder.to(device)
decoder = decoder.to(device)
print('Models built and ready to go!')
# Out:
# Building encoder and decoder ...
# Models built and ready to go!

# %%
# Configure training/optimization
clip = 50.0
teacher_forcing_ratio = 1.0
learning_rate = 0.0001
decoder_learning_ratio = 5.0
n_iteration = 4000
print_every = 1
save_every = 500

# Ensure dropout layers are in train mode
encoder.train()
decoder.train()

# Initialize optimizers
print('Building optimizers ...')
encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate * decoder_learning_ratio)
if loadFilename and os.path.isfile(loadFilename):
    encoder_optimizer.load_state_dict(encoder_optimizer_sd)
    decoder_optimizer.load_state_dict(decoder_optimizer_sd)

# If you have CUDA, configure CUDA to call
for state in encoder_optimizer.state.values():
    for k, v in state.items():
        if isinstance(v, torch.Tensor):
            state[k] = v.cuda()

for state in decoder_optimizer.state.values():
    for k, v in state.items():
        if isinstance(v, torch.Tensor):
            state[k] = v.cuda()

# Run training iterations
print("Starting Training!")
trainIters(model_name, voc, pairs, encoder, decoder, encoder_optimizer, decoder_optimizer,
           embedding, encoder_n_layers, decoder_n_layers, save_dir, n_iteration, batch_size,
           print_every, save_every, clip, corpus_name, loadFilename)
# Out:
# Building optimizers ...
# Starting Training!
# Initializing ...
# Training...
# Iteration: 1; Percent complete: 0.0%; Average loss: 9.7971
# Iteration: 2; Percent complete: 0.1%; Average loss: 9.7524
# Iteration: 3; Percent complete: 0.1%; Average loss: 9.6980
# Iteration: 4; Percent complete: 0.1%; Average loss: 9.5964
# Iteration: 5; Percent complete: 0.1%; Average loss: 9.4489
# Iteration: 6; Percent complete: 0.1%; Average loss: 9.1887
# Iteration: 7; Percent complete: 0.2%; Average loss: 8.7726
# Iteration: 8; Percent complete: 0.2%; Average loss: 8.3032
# Iteration: 9; Percent complete: 0.2%; Average loss: 8.3951
# Iteration: 10; Percent complete: 0.2%; Average loss: 8.3470
# Iteration: 11; Percent complete: 0.3%; Average loss: 8.3227
# Iteration: 12; Percent complete: 0.3%; Average loss: 8.0833
# Iteration: 13; Percent complete: 0.3%; Average loss: 7.8220
# Iteration: 14; Percent complete: 0.4%; Average loss: 7.5403
# Iteration: 15; Percent complete: 0.4%; Average loss: 7.2051
# Iteration: 16; Percent complete: 0.4%; Average loss: 6.8828
# Iteration: 17; Percent complete: 0.4%; Average loss: 6.8541
# Iteration: 18; Percent complete: 0.4%; Average loss: 6.5698
# Iteration: 19; Percent complete: 0.5%; Average loss: 6.7322
# Iteration: 20; Percent complete: 0.5%; Average loss: 6.5774
# Iteration: 21; Percent complete: 0.5%; Average loss: 6.3815
# Iteration: 22; Percent complete: 0.5%; Average loss: 6.4929
# Iteration: 23; Percent complete: 0.6%; Average loss: 6.3355
# Iteration: 24; Percent complete: 0.6%; Average loss: 6.4655
# Iteration: 25; Percent complete: 0.6%; Average loss: 6.4404
# Iteration: 26; Percent complete: 0.7%; Average loss: 6.2774
# Iteration: 27; Percent complete: 0.7%; Average loss: 6.4921
# Iteration: 28; Percent complete: 0.7%; Average loss: 6.3264
# Iteration: 29; Percent complete: 0.7%; Average loss: 6.1573
# Iteration: 30; Percent complete: 0.8%; Average loss: 6.4748
# Iteration: 31; Percent complete: 0.8%; Average loss: 6.3472
# Iteration: 32; Percent complete: 0.8%; Average loss: 6.3417
# Iteration: 33; Percent complete: 0.8%; Average loss: 6.3923
# Iteration: 34; Percent complete: 0.9%; Average loss: 6.2608
# Iteration: 35; Percent complete: 0.9%; Average loss: 6.2921
# Iteration: 36; Percent complete: 0.9%; Average loss: 5.9903
# Iteration: 37; Percent complete: 0.9%; Average loss: 6.3437
# Iteration: 38; Percent complete: 0.9%; Average loss: 5.9508
# Iteration: 39; Percent complete: 1.0%; Average loss: 6.1046
# Iteration: 40; Percent complete: 1.0%; Average loss: 6.1087
# Iteration: 41; Percent complete: 1.0%; Average loss: 6.1508
# Iteration: 42; Percent complete: 1.1%; Average loss: 6.3770
# Iteration: 43; Percent complete: 1.1%; Average loss: 6.3788
# Iteration: 44; Percent complete: 1.1%; Average loss: 6.1859
# Iteration: 45; Percent complete: 1.1%; Average loss: 6.3245
# Iteration: 46; Percent complete: 1.1%; Average loss: 6.1388
# Iteration: 47; Percent complete: 1.2%; Average loss: 6.3048
# Iteration: 48; Percent complete: 1.2%; Average loss: 6.0211
# Iteration: 49; Percent complete: 1.2%; Average loss: 6.1878
# Iteration: 50; Percent complete: 1.2%; Average loss: 6.2294
# Iteration: 51; Percent complete: 1.3%; Average loss: 6.0713
# Iteration: 52; Percent complete: 1.3%; Average loss: 6.1094
# Iteration: 53; Percent complete: 1.3%; Average loss: 6.2079
# Iteration: 54; Percent complete: 1.4%; Average loss: 6.3858
# Iteration: 55; Percent complete: 1.4%; Average loss: 6.4753
# Iteration: 56; Percent complete: 1.4%; Average loss: 6.3569
# Iteration: 57; Percent complete: 1.4%; Average loss: 6.2225
# Iteration: 58; Percent complete: 1.5%; Average loss: 6.2232
# Iteration: 59; Percent complete: 1.5%; Average loss: 6.1101
# Iteration: 60; Percent complete: 1.5%; Average loss: 6.0173
# Iteration: 61; Percent complete: 1.5%; Average loss: 6.2695
# Iteration: 62; Percent complete: 1.6%; Average loss: 6.1000
# Iteration: 63; Percent complete: 1.6%; Average loss: 6.1761
# Iteration: 64; Percent complete: 1.6%; Average loss: 5.8588
# Iteration: 65; Percent complete: 1.6%; Average loss: 6.1953
# Iteration: 66; Percent complete: 1.7%; Average loss: 6.1250
# Iteration: 67; Percent complete: 1.7%; Average loss: 6.3043
# Iteration: 68; Percent complete: 1.7%; Average loss: 6.0815
# Iteration: 69; Percent complete: 1.7%; Average loss: 5.9504
# Iteration: 70; Percent complete: 1.8%; Average loss: 6.1435
# Iteration: 71; Percent complete: 1.8%; Average loss: 6.1770
# Iteration: 72; Percent complete: 1.8%; Average loss: 6.0563
# Iteration: 73; Percent complete: 1.8%; Average loss: 6.1281
# Iteration: 74; Percent complete: 1.8%; Average loss: 6.1884
# Iteration: 75; Percent complete: 1.9%; Average loss: 6.2913
# Iteration: 76; Percent complete: 1.9%; Average loss: 6.0230
# Iteration: 77; Percent complete: 1.9%; Average loss: 6.0512
# Iteration: 78; Percent complete: 1.9%; Average loss: 5.8177
# Iteration: 79; Percent complete: 2.0%; Average loss: 6.0280
# Iteration: 80; Percent complete: 2.0%; Average loss: 6.0876
# Iteration: 81; Percent complete: 2.0%; Average loss: 6.0389
# Iteration: 82; Percent complete: 2.1%; Average loss: 5.7361
# Iteration: 83; Percent complete: 2.1%; Average loss: 6.0332
# Iteration: 84; Percent complete: 2.1%; Average loss: 6.0355
# Iteration: 85; Percent complete: 2.1%; Average loss: 6.1866
# Iteration: 86; Percent complete: 2.1%; Average loss: 5.9699
# Iteration: 87; Percent complete: 2.2%; Average loss: 6.2202
# Iteration: 88; Percent complete: 2.2%; Average loss: 6.4283
# Iteration: 89; Percent complete: 2.2%; Average loss: 5.9456
# Iteration: 90; Percent complete: 2.2%; Average loss: 5.9515
# Iteration: 91; Percent complete: 2.3%; Average loss: 6.1251
# Iteration: 92; Percent complete: 2.3%; Average loss: 5.9416
# Iteration: 93; Percent complete: 2.3%; Average loss: 5.8659
# Iteration: 94; Percent complete: 2.4%; Average loss: 6.1740
# Iteration: 95; Percent complete: 2.4%; Average loss: 6.1061
# Iteration: 96; Percent complete: 2.4%; Average loss: 5.8045
# Iteration: 97; Percent complete: 2.4%; Average loss: 6.1320
# Iteration: 98; Percent complete: 2.5%; Average loss: 5.9824
# Iteration: 99; Percent complete: 2.5%; Average loss: 6.1528
# Iteration: 100; Percent complete: 2.5%; Average loss: 6.0896
# Iteration: 101; Percent complete: 2.5%; Average loss: 6.0506
# Iteration: 102; Percent complete: 2.5%; Average loss: 5.9784
# Iteration: 103; Percent complete: 2.6%; Average loss: 5.8994
# Iteration: 104; Percent complete: 2.6%; Average loss: 5.7960
# Iteration: 105; Percent complete: 2.6%; Average loss: 5.8944
# Iteration: 106; Percent complete: 2.6%; Average loss: 6.1092
# Iteration: 107; Percent complete: 2.7%; Average loss: 5.9708
# Iteration: 108; Percent complete: 2.7%; Average loss: 6.0616
# Iteration: 109; Percent complete: 2.7%; Average loss: 5.8756
# Iteration: 110; Percent complete: 2.8%; Average loss: 5.8782
# Iteration: 111; Percent complete: 2.8%; Average loss: 6.1435
# Iteration: 112; Percent complete: 2.8%; Average loss: 5.9903
# Iteration: 113; Percent complete: 2.8%; Average loss: 6.0777
# Iteration: 114; Percent complete: 2.9%; Average loss: 5.7898
# Iteration: 115; Percent complete: 2.9%; Average loss: 6.0583
# Iteration: 116; Percent complete: 2.9%; Average loss: 5.9834
# Iteration: 117; Percent complete: 2.9%; Average loss: 6.1363
# Iteration: 118; Percent complete: 2.9%; Average loss: 5.8130
# Iteration: 119; Percent complete: 3.0%; Average loss: 5.7402
# Iteration: 120; Percent complete: 3.0%; Average loss: 5.7113
# Iteration: 121; Percent complete: 3.0%; Average loss: 5.9813
# Iteration: 122; Percent complete: 3.0%; Average loss: 6.2568
# Iteration: 123; Percent complete: 3.1%; Average loss: 5.9845
# Iteration: 124; Percent complete: 3.1%; Average loss: 6.1124
# Iteration: 125; Percent complete: 3.1%; Average loss: 5.9678
# Iteration: 126; Percent complete: 3.1%; Average loss: 5.9802
# Iteration: 127; Percent complete: 3.2%; Average loss: 6.0551
# Iteration: 128; Percent complete: 3.2%; Average loss: 5.9777
# Iteration: 129; Percent complete: 3.2%; Average loss: 6.0528
# Iteration: 130; Percent complete: 3.2%; Average loss: 5.7422
# Iteration: 131; Percent complete: 3.3%; Average loss: 5.9410
# Iteration: 132; Percent complete: 3.3%; Average loss: 6.0311
# Iteration: 133; Percent complete: 3.3%; Average loss: 5.9318
# Iteration: 134; Percent complete: 3.4%; Average loss: 5.9701
# Iteration: 135; Percent complete: 3.4%; Average loss: 5.7944
# Iteration: 136; Percent complete: 3.4%; Average loss: 6.2290
# Iteration: 137; Percent complete: 3.4%; Average loss: 5.7725
# Iteration: 138; Percent complete: 3.5%; Average loss: 6.0421
# Iteration: 139; Percent complete: 3.5%; Average loss: 5.8432
# Iteration: 140; Percent complete: 3.5%; Average loss: 5.8565
# Iteration: 141; Percent complete: 3.5%; Average loss: 6.1912
# Iteration: 142; Percent complete: 3.5%; Average loss: 5.8112
# Iteration: 143; Percent complete: 3.6%; Average loss: 5.8450
# Iteration: 144; Percent complete: 3.6%; Average loss: 6.1738
# Iteration: 145; Percent complete: 3.6%; Average loss: 6.0275
# Iteration: 146; Percent complete: 3.6%; Average loss: 5.8543
# Iteration: 147; Percent complete: 3.7%; Average loss: 5.7630
# Iteration: 148; Percent complete: 3.7%; Average loss: 5.8943
# Iteration: 149; Percent complete: 3.7%; Average loss: 6.1956
# Iteration: 150; Percent complete: 3.8%; Average loss: 5.8989
# Iteration: 151; Percent complete: 3.8%; Average loss: 5.8759
# Iteration: 152; Percent complete: 3.8%; Average loss: 5.9602
# Iteration: 153; Percent complete: 3.8%; Average loss: 5.9176
# Iteration: 154; Percent complete: 3.9%; Average loss: 5.9327
# Iteration: 155; Percent complete: 3.9%; Average loss: 5.9135
# Iteration: 156; Percent complete: 3.9%; Average loss: 5.9957
# Iteration: 157; Percent complete: 3.9%; Average loss: 6.0102
# Iteration: 158; Percent complete: 4.0%; Average loss: 5.7690
# Iteration: 159; Percent complete: 4.0%; Average loss: 6.0275
# Iteration: 160; Percent complete: 4.0%; Average loss: 5.8082
# Iteration: 161; Percent complete: 4.0%; Average loss: 5.6925
# Iteration: 162; Percent complete: 4.0%; Average loss: 5.9451
# Iteration: 163; Percent complete: 4.1%; Average loss: 5.7619
# Iteration: 164; Percent complete: 4.1%; Average loss: 5.8139
# Iteration: 165; Percent complete: 4.1%; Average loss: 5.9359
# Iteration: 166; Percent complete: 4.2%; Average loss: 5.8939
# Iteration: 167; Percent complete: 4.2%; Average loss: 5.8613
# Iteration: 168; Percent complete: 4.2%; Average loss: 5.5413
# Iteration: 169; Percent complete: 4.2%; Average loss: 5.8489
# Iteration: 170; Percent complete: 4.2%; Average loss: 5.9826
# Iteration: 171; Percent complete: 4.3%; Average loss: 5.8189
# Iteration: 172; Percent complete: 4.3%; Average loss: 5.8884
# Iteration: 173; Percent complete: 4.3%; Average loss: 5.6786
# Iteration: 174; Percent complete: 4.3%; Average loss: 5.8839
# Iteration: 175; Percent complete: 4.4%; Average loss: 5.8963
# Iteration: 176; Percent complete: 4.4%; Average loss: 5.6142
# Iteration: 177; Percent complete: 4.4%; Average loss: 5.9850
# Iteration: 178; Percent complete: 4.5%; Average loss: 5.7968
# Iteration: 179; Percent complete: 4.5%; Average loss: 5.6707
# Iteration: 180; Percent complete: 4.5%; Average loss: 5.8149
# Iteration: 181; Percent complete: 4.5%; Average loss: 5.6909
# Iteration: 182; Percent complete: 4.5%; Average loss: 5.9272
# Iteration: 183; Percent complete: 4.6%; Average loss: 6.0139
# Iteration: 184; Percent complete: 4.6%; Average loss: 5.8301
# Iteration: 185; Percent complete: 4.6%; Average loss: 5.7993
# Iteration: 186; Percent complete: 4.7%; Average loss: 5.6124
# Iteration: 187; Percent complete: 4.7%; Average loss: 5.9215
# Iteration: 188; Percent complete: 4.7%; Average loss: 5.8904
# Iteration: 189; Percent complete: 4.7%; Average loss: 5.7835
# Iteration: 190; Percent complete: 4.8%; Average loss: 5.8817
# Iteration: 191; Percent complete: 4.8%; Average loss: 5.9294
# Iteration: 192; Percent complete: 4.8%; Average loss: 5.6421
# Iteration: 193; Percent complete: 4.8%; Average loss: 5.6605
# Iteration: 194; Percent complete: 4.9%; Average loss: 5.7036
# Iteration: 195; Percent complete: 4.9%; Average loss: 5.4484
# Iteration: 196; Percent complete: 4.9%; Average loss: 5.8679
# Iteration: 197; Percent complete: 4.9%; Average loss: 5.7840
# Iteration: 198; Percent complete: 5.0%; Average loss: 5.6087
# Iteration: 199; Percent complete: 5.0%; Average loss: 5.6970
# Iteration: 200; Percent complete: 5.0%; Average loss: 5.9211
# Iteration: 201; Percent complete: 5.0%; Average loss: 5.6769
# Iteration: 202; Percent complete: 5.1%; Average loss: 5.7026
# Iteration: 203; Percent complete: 5.1%; Average loss: 5.7098
# Iteration: 204; Percent complete: 5.1%; Average loss: 5.8577
# Iteration: 205; Percent complete: 5.1%; Average loss: 5.8473
# Iteration: 206; Percent complete: 5.1%; Average loss: 5.8245
# Iteration: 207; Percent complete: 5.2%; Average loss: 5.6703
# Iteration: 208; Percent complete: 5.2%; Average loss: 5.7998
# Iteration: 209; Percent complete: 5.2%; Average loss: 5.7227
# Iteration: 210; Percent complete: 5.2%; Average loss: 5.8448
# Iteration: 211; Percent complete: 5.3%; Average loss: 5.6004
# Iteration: 212; Percent complete: 5.3%; Average loss: 5.6580
# Iteration: 213; Percent complete: 5.3%; Average loss: 5.8660
# Iteration: 214; Percent complete: 5.3%; Average loss: 5.6985
# Iteration: 215; Percent complete: 5.4%; Average loss: 5.8292
# Iteration: 216; Percent complete: 5.4%; Average loss: 5.6275
# Iteration: 217; Percent complete: 5.4%; Average loss: 5.6900
# Iteration: 218; Percent complete: 5.5%; Average loss: 5.7912
# Iteration: 219; Percent complete: 5.5%; Average loss: 5.7739
# Iteration: 220; Percent complete: 5.5%; Average loss: 5.8469
# Iteration: 221; Percent complete: 5.5%; Average loss: 5.6510
# Iteration: 222; Percent complete: 5.5%; Average loss: 5.4023
# Iteration: 223; Percent complete: 5.6%; Average loss: 5.5936
# Iteration: 224; Percent complete: 5.6%; Average loss: 5.8278
# Iteration: 225; Percent complete: 5.6%; Average loss: 5.3939
# Iteration: 226; Percent complete: 5.7%; Average loss: 5.5930
# Iteration: 227; Percent complete: 5.7%; Average loss: 5.6299
# Iteration: 228; Percent complete: 5.7%; Average loss: 5.6997
# Iteration: 229; Percent complete: 5.7%; Average loss: 5.5665
# Iteration: 230; Percent complete: 5.8%; Average loss: 5.6885
# Iteration: 231; Percent complete: 5.8%; Average loss: 5.7357
# Iteration: 232; Percent complete: 5.8%; Average loss: 5.8411
# Iteration: 233; Percent complete: 5.8%; Average loss: 5.5313
# Iteration: 234; Percent complete: 5.9%; Average loss: 5.3356
# Iteration: 235; Percent complete: 5.9%; Average loss: 5.5865
# Iteration: 236; Percent complete: 5.9%; Average loss: 5.5613
# Iteration: 237; Percent complete: 5.9%; Average loss: 5.9145
# Iteration: 238; Percent complete: 5.9%; Average loss: 5.8425
# Iteration: 239; Percent complete: 6.0%; Average loss: 5.7742
# Iteration: 240; Percent complete: 6.0%; Average loss: 5.4929
# Iteration: 241; Percent complete: 6.0%; Average loss: 5.5458
# Iteration: 242; Percent complete: 6.0%; Average loss: 5.8729
# Iteration: 243; Percent complete: 6.1%; Average loss: 5.3923
# Iteration: 244; Percent complete: 6.1%; Average loss: 5.6849
# Iteration: 245; Percent complete: 6.1%; Average loss: 5.7071
# Iteration: 246; Percent complete: 6.2%; Average loss: 5.3839
# Iteration: 247; Percent complete: 6.2%; Average loss: 5.6730
# Iteration: 248; Percent complete: 6.2%; Average loss: 5.7046
# Iteration: 249; Percent complete: 6.2%; Average loss: 5.5904
# Iteration: 250; Percent complete: 6.2%; Average loss: 5.5513
# Iteration: 251; Percent complete: 6.3%; Average loss: 5.7002
# Iteration: 252; Percent complete: 6.3%; Average loss: 5.5185
# Iteration: 253; Percent complete: 6.3%; Average loss: 5.6668
# Iteration: 254; Percent complete: 6.3%; Average loss: 5.4721
# Iteration: 255; Percent complete: 6.4%; Average loss: 5.5205
# Iteration: 256; Percent complete: 6.4%; Average loss: 5.5825
# Iteration: 257; Percent complete: 6.4%; Average loss: 5.7796
# Iteration: 258; Percent complete: 6.5%; Average loss: 5.6061
# Iteration: 259; Percent complete: 6.5%; Average loss: 5.6033
# Iteration: 260; Percent complete: 6.5%; Average loss: 5.7309
# Iteration: 261; Percent complete: 6.5%; Average loss: 5.5548
# Iteration: 262; Percent complete: 6.6%; Average loss: 5.4563
# Iteration: 263; Percent complete: 6.6%; Average loss: 5.5214
# Iteration: 264; Percent complete: 6.6%; Average loss: 5.5842
# Iteration: 265; Percent complete: 6.6%; Average loss: 5.3962
# Iteration: 266; Percent complete: 6.7%; Average loss: 5.5574
# Iteration: 267; Percent complete: 6.7%; Average loss: 5.3273
# Iteration: 268; Percent complete: 6.7%; Average loss: 5.6279
# Iteration: 269; Percent complete: 6.7%; Average loss: 5.6723
# Iteration: 270; Percent complete: 6.8%; Average loss: 5.7215
# Iteration: 271; Percent complete: 6.8%; Average loss: 5.6330
# Iteration: 272; Percent complete: 6.8%; Average loss: 5.6607
# Iteration: 273; Percent complete: 6.8%; Average loss: 5.5529
# Iteration: 274; Percent complete: 6.9%; Average loss: 5.5274
# Iteration: 275; Percent complete: 6.9%; Average loss: 5.5988
# Iteration: 276; Percent complete: 6.9%; Average loss: 5.5818
# Iteration: 277; Percent complete: 6.9%; Average loss: 5.7477
# Iteration: 278; Percent complete: 7.0%; Average loss: 5.5261
# Iteration: 279; Percent complete: 7.0%; Average loss: 5.6850
# Iteration: 280; Percent complete: 7.0%; Average loss: 5.5823
# Iteration: 281; Percent complete: 7.0%; Average loss: 5.5817
# Iteration: 282; Percent complete: 7.0%; Average loss: 5.3516
# Iteration: 283; Percent complete: 7.1%; Average loss: 5.7092
# Iteration: 284; Percent complete: 7.1%; Average loss: 5.5935
# Iteration: 285; Percent complete: 7.1%; Average loss: 5.7178
# Iteration: 286; Percent complete: 7.1%; Average loss: 5.5301
# Iteration: 287; Percent complete: 7.2%; Average loss: 5.1358
# Iteration: 288; Percent complete: 7.2%; Average loss: 5.4852
# Iteration: 289; Percent complete: 7.2%; Average loss: 5.6190
# Iteration: 290; Percent complete: 7.2%; Average loss: 5.6226
# Iteration: 291; Percent complete: 7.3%; Average loss: 5.6138
# Iteration: 292; Percent complete: 7.3%; Average loss: 5.7351
# Iteration: 293; Percent complete: 7.3%; Average loss: 5.6332
# Iteration: 294; Percent complete: 7.3%; Average loss: 5.6111
# Iteration: 295; Percent complete: 7.4%; Average loss: 5.4786
# Iteration: 296; Percent complete: 7.4%; Average loss: 5.3463
# Iteration: 297; Percent complete: 7.4%; Average loss: 5.5452
# Iteration: 298; Percent complete: 7.4%; Average loss: 5.4264
# Iteration: 299; Percent complete: 7.5%; Average loss: 5.3981
# Iteration: 300; Percent complete: 7.5%; Average loss: 5.3979
# Iteration: 301; Percent complete: 7.5%; Average loss: 5.6431
# Iteration: 302; Percent complete: 7.5%; Average loss: 5.4643
# Iteration: 303; Percent complete: 7.6%; Average loss: 5.4085
# Iteration: 304; Percent complete: 7.6%; Average loss: 5.6799
# Iteration: 305; Percent complete: 7.6%; Average loss: 5.3815
# Iteration: 306; Percent complete: 7.6%; Average loss: 5.6860
# Iteration: 307; Percent complete: 7.7%; Average loss: 5.2986
# Iteration: 308; Percent complete: 7.7%; Average loss: 5.3281
# Iteration: 309; Percent complete: 7.7%; Average loss: 5.4413
# Iteration: 310; Percent complete: 7.8%; Average loss: 5.7595
# Iteration: 311; Percent complete: 7.8%; Average loss: 5.5469
# Iteration: 312; Percent complete: 7.8%; Average loss: 5.4540
# Iteration: 313; Percent complete: 7.8%; Average loss: 5.5752
# Iteration: 314; Percent complete: 7.8%; Average loss: 5.5434
# Iteration: 315; Percent complete: 7.9%; Average loss: 5.5270
# Iteration: 316; Percent complete: 7.9%; Average loss: 5.5154
# Iteration: 317; Percent complete: 7.9%; Average loss: 5.4828
# Iteration: 318; Percent complete: 8.0%; Average loss: 5.5192
# Iteration: 319; Percent complete: 8.0%; Average loss: 5.6046
# Iteration: 320; Percent complete: 8.0%; Average loss: 5.5058
# Iteration: 321; Percent complete: 8.0%; Average loss: 5.2084
# Iteration: 322; Percent complete: 8.1%; Average loss: 5.3615
# Iteration: 323; Percent complete: 8.1%; Average loss: 5.5803
# Iteration: 324; Percent complete: 8.1%; Average loss: 5.4065
# Iteration: 325; Percent complete: 8.1%; Average loss: 5.5411
# Iteration: 326; Percent complete: 8.2%; Average loss: 5.3767
# Iteration: 327; Percent complete: 8.2%; Average loss: 5.4774
# Iteration: 328; Percent complete: 8.2%; Average loss: 5.5691
# Iteration: 329; Percent complete: 8.2%; Average loss: 5.3686
# Iteration: 330; Percent complete: 8.2%; Average loss: 5.1995
# Iteration: 331; Percent complete: 8.3%; Average loss: 5.1556
# Iteration: 332; Percent complete: 8.3%; Average loss: 5.3725
# Iteration: 333; Percent complete: 8.3%; Average loss: 5.5782
# Iteration: 334; Percent complete: 8.3%; Average loss: 5.5430
# Iteration: 335; Percent complete: 8.4%; Average loss: 5.3952
# Iteration: 336; Percent complete: 8.4%; Average loss: 5.2703
# Iteration: 337; Percent complete: 8.4%; Average loss: 5.1680
# Iteration: 338; Percent complete: 8.5%; Average loss: 5.3043
# Iteration: 339; Percent complete: 8.5%; Average loss: 5.3241
# Iteration: 340; Percent complete: 8.5%; Average loss: 5.1318
# Iteration: 341; Percent complete: 8.5%; Average loss: 5.5015
# Iteration: 342; Percent complete: 8.6%; Average loss: 5.4385
# Iteration: 343; Percent complete: 8.6%; Average loss: 5.1995
# Iteration: 344; Percent complete: 8.6%; Average loss: 5.2981
# Iteration: 345; Percent complete: 8.6%; Average loss: 5.4317
# Iteration: 346; Percent complete: 8.6%; Average loss: 5.2294
# Iteration: 347; Percent complete: 8.7%; Average loss: 5.2508
# Iteration: 348; Percent complete: 8.7%; Average loss: 5.2747
# Iteration: 349; Percent complete: 8.7%; Average loss: 5.6434
# Iteration: 350; Percent complete: 8.8%; Average loss: 5.3636
# Iteration: 351; Percent complete: 8.8%; Average loss: 5.5564
# Iteration: 352; Percent complete: 8.8%; Average loss: 5.1746
# Iteration: 353; Percent complete: 8.8%; Average loss: 5.3776
# Iteration: 354; Percent complete: 8.8%; Average loss: 5.3341
# Iteration: 355; Percent complete: 8.9%; Average loss: 5.2395
# Iteration: 356; Percent complete: 8.9%; Average loss: 5.2003
# Iteration: 357; Percent complete: 8.9%; Average loss: 5.3733
# Iteration: 358; Percent complete: 8.9%; Average loss: 5.2833
# Iteration: 359; Percent complete: 9.0%; Average loss: 5.4511
# Iteration: 360; Percent complete: 9.0%; Average loss: 5.4857
# Iteration: 361; Percent complete: 9.0%; Average loss: 5.3222
# Iteration: 362; Percent complete: 9.0%; Average loss: 5.2762
# Iteration: 363; Percent complete: 9.1%; Average loss: 5.3316
# Iteration: 364; Percent complete: 9.1%; Average loss: 5.2680
# Iteration: 365; Percent complete: 9.1%; Average loss: 5.4552
# Iteration: 366; Percent complete: 9.2%; Average loss: 5.2316
# Iteration: 367; Percent complete: 9.2%; Average loss: 5.4083
# Iteration: 368; Percent complete: 9.2%; Average loss: 5.1159
# Iteration: 369; Percent complete: 9.2%; Average loss: 5.3542
# Iteration: 370; Percent complete: 9.2%; Average loss: 5.3834
# Iteration: 371; Percent complete: 9.3%; Average loss: 5.3359
# Iteration: 372; Percent complete: 9.3%; Average loss: 5.2082
# Iteration: 373; Percent complete: 9.3%; Average loss: 5.3304
# Iteration: 374; Percent complete: 9.3%; Average loss: 5.4032
# Iteration: 375; Percent complete: 9.4%; Average loss: 5.3806
# Iteration: 376; Percent complete: 9.4%; Average loss: 5.1828
# Iteration: 377; Percent complete: 9.4%; Average loss: 5.2956
# Iteration: 378; Percent complete: 9.4%; Average loss: 5.4462
# Iteration: 379; Percent complete: 9.5%; Average loss: 5.1828
# Iteration: 380; Percent complete: 9.5%; Average loss: 5.3348
# Iteration: 381; Percent complete: 9.5%; Average loss: 5.2912
# Iteration: 382; Percent complete: 9.6%; Average loss: 5.2595
# Iteration: 383; Percent complete: 9.6%; Average loss: 5.4096
# Iteration: 384; Percent complete: 9.6%; Average loss: 5.2718
# Iteration: 385; Percent complete: 9.6%; Average loss: 5.2026
# Iteration: 386; Percent complete: 9.7%; Average loss: 4.9789
# Iteration: 387; Percent complete: 9.7%; Average loss: 5.4030
# Iteration: 388; Percent complete: 9.7%; Average loss: 5.3403
# Iteration: 389; Percent complete: 9.7%; Average loss: 5.5452
# Iteration: 390; Percent complete: 9.8%; Average loss: 5.2679
# Iteration: 391; Percent complete: 9.8%; Average loss: 5.2341
# Iteration: 392; Percent complete: 9.8%; Average loss: 5.2995
# Iteration: 393; Percent complete: 9.8%; Average loss: 5.0545
# Iteration: 394; Percent complete: 9.8%; Average loss: 5.3058
# Iteration: 395; Percent complete: 9.9%; Average loss: 5.3686
# Iteration: 396; Percent complete: 9.9%; Average loss: 5.3947
# Iteration: 397; Percent complete: 9.9%; Average loss: 5.2739
# Iteration: 398; Percent complete: 10.0%; Average loss: 5.4746
# Iteration: 399; Percent complete: 10.0%; Average loss: 5.2935
# Iteration: 400; Percent complete: 10.0%; Average loss: 5.1044
# Iteration: 401; Percent complete: 10.0%; Average loss: 5.5426
# Iteration: 402; Percent complete: 10.1%; Average loss: 5.3177
# Iteration: 403; Percent complete: 10.1%; Average loss: 5.2590
# Iteration: 404; Percent complete: 10.1%; Average loss: 5.3386
# Iteration: 405; Percent complete: 10.1%; Average loss: 5.5031
# Iteration: 406; Percent complete: 10.2%; Average loss: 5.2853
# Iteration: 407; Percent complete: 10.2%; Average loss: 5.5899
# Iteration: 408; Percent complete: 10.2%; Average loss: 5.5137
# Iteration: 409; Percent complete: 10.2%; Average loss: 5.1668
# Iteration: 410; Percent complete: 10.2%; Average loss: 5.4978
# Iteration: 411; Percent complete: 10.3%; Average loss: 5.2702
# Iteration: 412; Percent complete: 10.3%; Average loss: 5.2419
# Iteration: 413; Percent complete: 10.3%; Average loss: 5.1565
# Iteration: 414; Percent complete: 10.3%; Average loss: 5.5517
# Iteration: 415; Percent complete: 10.4%; Average loss: 5.6562
# Iteration: 416; Percent complete: 10.4%; Average loss: 5.5380
# Iteration: 417; Percent complete: 10.4%; Average loss: 5.1441
# Iteration: 418; Percent complete: 10.4%; Average loss: 5.1886
# Iteration: 419; Percent complete: 10.5%; Average loss: 5.3592
# Iteration: 420; Percent complete: 10.5%; Average loss: 4.7440
# Iteration: 421; Percent complete: 10.5%; Average loss: 5.2060
# Iteration: 422; Percent complete: 10.5%; Average loss: 5.2720
# Iteration: 423; Percent complete: 10.6%; Average loss: 5.4541
# Iteration: 424; Percent complete: 10.6%; Average loss: 5.1828
# Iteration: 425; Percent complete: 10.6%; Average loss: 5.0781
# Iteration: 426; Percent complete: 10.7%; Average loss: 5.3860
# Iteration: 427; Percent complete: 10.7%; Average loss: 5.3934
# Iteration: 428; Percent complete: 10.7%; Average loss: 5.2598
# Iteration: 429; Percent complete: 10.7%; Average loss: 5.2152
# Iteration: 430; Percent complete: 10.8%; Average loss: 5.3636
# Iteration: 431; Percent complete: 10.8%; Average loss: 5.1736
# Iteration: 432; Percent complete: 10.8%; Average loss: 5.0534
# Iteration: 433; Percent complete: 10.8%; Average loss: 5.6014
# Iteration: 434; Percent complete: 10.8%; Average loss: 5.4972
# Iteration: 435; Percent complete: 10.9%; Average loss: 5.1730
# Iteration: 436; Percent complete: 10.9%; Average loss: 5.4507
# Iteration: 437; Percent complete: 10.9%; Average loss: 5.3539
# Iteration: 438; Percent complete: 10.9%; Average loss: 5.4711
# Iteration: 439; Percent complete: 11.0%; Average loss: 5.1876
# Iteration: 440; Percent complete: 11.0%; Average loss: 5.2148
# Iteration: 441; Percent complete: 11.0%; Average loss: 5.2208
# Iteration: 442; Percent complete: 11.1%; Average loss: 5.3088
# Iteration: 443; Percent complete: 11.1%; Average loss: 5.3662
# Iteration: 444; Percent complete: 11.1%; Average loss: 5.2005
# Iteration: 445; Percent complete: 11.1%; Average loss: 5.2881
# Iteration: 446; Percent complete: 11.2%; Average loss: 5.4709
# Iteration: 447; Percent complete: 11.2%; Average loss: 5.2471
# Iteration: 448; Percent complete: 11.2%; Average loss: 5.2515
# Iteration: 449; Percent complete: 11.2%; Average loss: 5.1453
# Iteration: 450; Percent complete: 11.2%; Average loss: 5.4641
# Iteration: 451; Percent complete: 11.3%; Average loss: 5.2424
# Iteration: 452; Percent complete: 11.3%; Average loss: 5.5062
# Iteration: 453; Percent complete: 11.3%; Average loss: 5.1441
# Iteration: 454; Percent complete: 11.3%; Average loss: 5.2370
# Iteration: 455; Percent complete: 11.4%; Average loss: 5.3600
# Iteration: 456; Percent complete: 11.4%; Average loss: 5.7164
# Iteration: 457; Percent complete: 11.4%; Average loss: 5.3220
# Iteration: 458; Percent complete: 11.5%; Average loss: 5.1101
# Iteration: 459; Percent complete: 11.5%; Average loss: 5.0840
# Iteration: 460; Percent complete: 11.5%; Average loss: 5.4007
# Iteration: 461; Percent complete: 11.5%; Average loss: 4.9757
# Iteration: 462; Percent complete: 11.6%; Average loss: 4.9741
# Iteration: 463; Percent complete: 11.6%; Average loss: 5.1851
# Iteration: 464; Percent complete: 11.6%; Average loss: 5.3703
# Iteration: 465; Percent complete: 11.6%; Average loss: 5.5325
# Iteration: 466; Percent complete: 11.7%; Average loss: 5.3899
# Iteration: 467; Percent complete: 11.7%; Average loss: 5.2537
# Iteration: 468; Percent complete: 11.7%; Average loss: 5.1362
# Iteration: 469; Percent complete: 11.7%; Average loss: 5.1846
# Iteration: 470; Percent complete: 11.8%; Average loss: 5.2753
# Iteration: 471; Percent complete: 11.8%; Average loss: 5.2608
# Iteration: 472; Percent complete: 11.8%; Average loss: 5.1911
# Iteration: 473; Percent complete: 11.8%; Average loss: 5.3991
# Iteration: 474; Percent complete: 11.8%; Average loss: 5.2491
# Iteration: 475; Percent complete: 11.9%; Average loss: 5.2291
# Iteration: 476; Percent complete: 11.9%; Average loss: 5.2028
# Iteration: 477; Percent complete: 11.9%; Average loss: 5.1993
# Iteration: 478; Percent complete: 11.9%; Average loss: 5.3766
# Iteration: 479; Percent complete: 12.0%; Average loss: 5.4245
# Iteration: 480; Percent complete: 12.0%; Average loss: 4.9220
# Iteration: 481; Percent complete: 12.0%; Average loss: 5.1953
# Iteration: 482; Percent complete: 12.0%; Average loss: 5.3073
# Iteration: 483; Percent complete: 12.1%; Average loss: 5.5409
# Iteration: 484; Percent complete: 12.1%; Average loss: 5.3659
# Iteration: 485; Percent complete: 12.1%; Average loss: 5.3307
# Iteration: 486; Percent complete: 12.2%; Average loss: 5.1737
# Iteration: 487; Percent complete: 12.2%; Average loss: 5.2970
# Iteration: 488; Percent complete: 12.2%; Average loss: 5.4561
# Iteration: 489; Percent complete: 12.2%; Average loss: 5.3303
# Iteration: 490; Percent complete: 12.2%; Average loss: 5.3257
# Iteration: 491; Percent complete: 12.3%; Average loss: 4.9250
# Iteration: 492; Percent complete: 12.3%; Average loss: 5.3317
# Iteration: 493; Percent complete: 12.3%; Average loss: 5.3781
# Iteration: 494; Percent complete: 12.3%; Average loss: 5.1285
# Iteration: 495; Percent complete: 12.4%; Average loss: 5.1830
# Iteration: 496; Percent complete: 12.4%; Average loss: 5.1106
# Iteration: 497; Percent complete: 12.4%; Average loss: 5.2046
# Iteration: 498; Percent complete: 12.4%; Average loss: 5.3601
# Iteration: 499; Percent complete: 12.5%; Average loss: 5.3561
# Iteration: 500; Percent complete: 12.5%; Average loss: 5.4205
# Iteration: 501; Percent complete: 12.5%; Average loss: 5.5361
# Iteration: 502; Percent complete: 12.6%; Average loss: 5.2249
# Iteration: 503; Percent complete: 12.6%; Average loss: 5.0323
# Iteration: 504; Percent complete: 12.6%; Average loss: 5.3558
# Iteration: 505; Percent complete: 12.6%; Average loss: 5.2815
# Iteration: 506; Percent complete: 12.7%; Average loss: 5.1741
# Iteration: 507; Percent complete: 12.7%; Average loss: 5.4371
# Iteration: 508; Percent complete: 12.7%; Average loss: 4.9436
# Iteration: 509; Percent complete: 12.7%; Average loss: 4.8951
# Iteration: 510; Percent complete: 12.8%; Average loss: 4.9849
# Iteration: 511; Percent complete: 12.8%; Average loss: 4.9438
# Iteration: 512; Percent complete: 12.8%; Average loss: 5.6383
# Iteration: 513; Percent complete: 12.8%; Average loss: 5.2472
# Iteration: 514; Percent complete: 12.8%; Average loss: 4.9170
# Iteration: 515; Percent complete: 12.9%; Average loss: 5.1637
# Iteration: 516; Percent complete: 12.9%; Average loss: 5.2696
# Iteration: 517; Percent complete: 12.9%; Average loss: 5.3423
# Iteration: 518; Percent complete: 13.0%; Average loss: 5.0316
# Iteration: 519; Percent complete: 13.0%; Average loss: 4.8498
# Iteration: 520; Percent complete: 13.0%; Average loss: 4.9386
# Iteration: 521; Percent complete: 13.0%; Average loss: 5.5390
# Iteration: 522; Percent complete: 13.1%; Average loss: 5.3189
# Iteration: 523; Percent complete: 13.1%; Average loss: 5.3372
# Iteration: 524; Percent complete: 13.1%; Average loss: 5.1380
# Iteration: 525; Percent complete: 13.1%; Average loss: 5.1732
# Iteration: 526; Percent complete: 13.2%; Average loss: 5.1896
# Iteration: 527; Percent complete: 13.2%; Average loss: 5.1628
# Iteration: 528; Percent complete: 13.2%; Average loss: 5.4431
# Iteration: 529; Percent complete: 13.2%; Average loss: 5.1632
# Iteration: 530; Percent complete: 13.2%; Average loss: 4.7445
# Iteration: 531; Percent complete: 13.3%; Average loss: 5.1421
# Iteration: 532; Percent complete: 13.3%; Average loss: 5.1422
# Iteration: 533; Percent complete: 13.3%; Average loss: 4.9097
# Iteration: 534; Percent complete: 13.4%; Average loss: 5.3252
# Iteration: 535; Percent complete: 13.4%; Average loss: 5.1694
# Iteration: 536; Percent complete: 13.4%; Average loss: 5.5645
# Iteration: 537; Percent complete: 13.4%; Average loss: 5.1473
# Iteration: 538; Percent complete: 13.5%; Average loss: 5.2129
# Iteration: 539; Percent complete: 13.5%; Average loss: 5.1567
# Iteration: 540; Percent complete: 13.5%; Average loss: 5.1839
# Iteration: 541; Percent complete: 13.5%; Average loss: 5.1401
# Iteration: 542; Percent complete: 13.6%; Average loss: 5.0961
# Iteration: 543; Percent complete: 13.6%; Average loss: 5.1147
# Iteration: 544; Percent complete: 13.6%; Average loss: 5.1077
# Iteration: 545; Percent complete: 13.6%; Average loss: 5.1337
# Iteration: 546; Percent complete: 13.7%; Average loss: 5.2968
# Iteration: 547; Percent complete: 13.7%; Average loss: 5.4332
# Iteration: 548; Percent complete: 13.7%; Average loss: 5.3034
# Iteration: 549; Percent complete: 13.7%; Average loss: 5.5188
# Iteration: 550; Percent complete: 13.8%; Average loss: 5.1834
# Iteration: 551; Percent complete: 13.8%; Average loss: 5.2491
# Iteration: 552; Percent complete: 13.8%; Average loss: 5.0825
# Iteration: 553; Percent complete: 13.8%; Average loss: 5.2157
# Iteration: 554; Percent complete: 13.9%; Average loss: 5.4206
# Iteration: 555; Percent complete: 13.9%; Average loss: 4.8096
# Iteration: 556; Percent complete: 13.9%; Average loss: 5.0972
# Iteration: 557; Percent complete: 13.9%; Average loss: 5.3303
# Iteration: 558; Percent complete: 14.0%; Average loss: 5.4674
# Iteration: 559; Percent complete: 14.0%; Average loss: 5.2705
# Iteration: 560; Percent complete: 14.0%; Average loss: 4.6825
# Iteration: 561; Percent complete: 14.0%; Average loss: 5.0067
# Iteration: 562; Percent complete: 14.1%; Average loss: 5.1430
# Iteration: 563; Percent complete: 14.1%; Average loss: 5.2052
# Iteration: 564; Percent complete: 14.1%; Average loss: 5.1310
# Iteration: 565; Percent complete: 14.1%; Average loss: 5.4098
# Iteration: 566; Percent complete: 14.1%; Average loss: 4.7544
# Iteration: 567; Percent complete: 14.2%; Average loss: 5.0775
# Iteration: 568; Percent complete: 14.2%; Average loss: 5.2563
# Iteration: 569; Percent complete: 14.2%; Average loss: 5.1080
# Iteration: 570; Percent complete: 14.2%; Average loss: 5.2399
# Iteration: 571; Percent complete: 14.3%; Average loss: 5.3221
# Iteration: 572; Percent complete: 14.3%; Average loss: 5.3220
# Iteration: 573; Percent complete: 14.3%; Average loss: 5.1812
# Iteration: 574; Percent complete: 14.3%; Average loss: 5.4140
# Iteration: 575; Percent complete: 14.4%; Average loss: 5.2970
# Iteration: 576; Percent complete: 14.4%; Average loss: 5.0596
# Iteration: 577; Percent complete: 14.4%; Average loss: 5.3346
# Iteration: 578; Percent complete: 14.4%; Average loss: 5.3425
# Iteration: 579; Percent complete: 14.5%; Average loss: 5.0266
# Iteration: 580; Percent complete: 14.5%; Average loss: 4.9940
# Iteration: 581; Percent complete: 14.5%; Average loss: 5.2502
# Iteration: 582; Percent complete: 14.5%; Average loss: 5.3372
# Iteration: 583; Percent complete: 14.6%; Average loss: 5.3140
# Iteration: 584; Percent complete: 14.6%; Average loss: 5.3147
# Iteration: 585; Percent complete: 14.6%; Average loss: 4.7815
# Iteration: 586; Percent complete: 14.6%; Average loss: 4.9931
# Iteration: 587; Percent complete: 14.7%; Average loss: 5.2074
# Iteration: 588; Percent complete: 14.7%; Average loss: 5.0715
# Iteration: 589; Percent complete: 14.7%; Average loss: 5.2718
# Iteration: 590; Percent complete: 14.8%; Average loss: 5.1277
# Iteration: 591; Percent complete: 14.8%; Average loss: 5.0130
# Iteration: 592; Percent complete: 14.8%; Average loss: 5.0662
# Iteration: 593; Percent complete: 14.8%; Average loss: 5.1161
# Iteration: 594; Percent complete: 14.8%; Average loss: 4.9654
# Iteration: 595; Percent complete: 14.9%; Average loss: 5.3128
# Iteration: 596; Percent complete: 14.9%; Average loss: 5.1961
# Iteration: 597; Percent complete: 14.9%; Average loss: 5.0446
# Iteration: 598; Percent complete: 14.9%; Average loss: 5.1698
# Iteration: 599; Percent complete: 15.0%; Average loss: 4.9466
# Iteration: 600; Percent complete: 15.0%; Average loss: 5.1330
# Iteration: 601; Percent complete: 15.0%; Average loss: 5.5850
# Iteration: 602; Percent complete: 15.0%; Average loss: 5.2064
# Iteration: 603; Percent complete: 15.1%; Average loss: 5.2799
# Iteration: 604; Percent complete: 15.1%; Average loss: 4.8412
# Iteration: 605; Percent complete: 15.1%; Average loss: 5.2759
# Iteration: 606; Percent complete: 15.2%; Average loss: 5.3181
# Iteration: 607; Percent complete: 15.2%; Average loss: 5.1964
# Iteration: 608; Percent complete: 15.2%; Average loss: 5.1704
# Iteration: 609; Percent complete: 15.2%; Average loss: 4.9919
# Iteration: 610; Percent complete: 15.2%; Average loss: 5.1981
# Iteration: 611; Percent complete: 15.3%; Average loss: 5.1084
# Iteration: 612; Percent complete: 15.3%; Average loss: 5.3222
# Iteration: 613; Percent complete: 15.3%; Average loss: 5.1785
# Iteration: 614; Percent complete: 15.3%; Average loss: 5.2083
# Iteration: 615; Percent complete: 15.4%; Average loss: 5.1808
# Iteration: 616; Percent complete: 15.4%; Average loss: 5.2829
# Iteration: 617; Percent complete: 15.4%; Average loss: 4.9250
# Iteration: 618; Percent complete: 15.4%; Average loss: 5.1808
# Iteration: 619; Percent complete: 15.5%; Average loss: 5.5250
# Iteration: 620; Percent complete: 15.5%; Average loss: 4.9292
# Iteration: 621; Percent complete: 15.5%; Average loss: 4.9487
# Iteration: 622; Percent complete: 15.6%; Average loss: 4.9404
# Iteration: 623; Percent complete: 15.6%; Average loss: 4.8149
# Iteration: 624; Percent complete: 15.6%; Average loss: 5.2738
# Iteration: 625; Percent complete: 15.6%; Average loss: 4.8560
# Iteration: 626; Percent complete: 15.7%; Average loss: 5.0997
# Iteration: 627; Percent complete: 15.7%; Average loss: 5.2574
# Iteration: 628; Percent complete: 15.7%; Average loss: 5.2120
# Iteration: 629; Percent complete: 15.7%; Average loss: 4.8781
# Iteration: 630; Percent complete: 15.8%; Average loss: 5.1778
# Iteration: 631; Percent complete: 15.8%; Average loss: 5.2690
# Iteration: 632; Percent complete: 15.8%; Average loss: 5.1434
# Iteration: 633; Percent complete: 15.8%; Average loss: 5.2087
# Iteration: 634; Percent complete: 15.8%; Average loss: 5.0754
# Iteration: 635; Percent complete: 15.9%; Average loss: 5.0114
# Iteration: 636; Percent complete: 15.9%; Average loss: 5.0441
# Iteration: 637; Percent complete: 15.9%; Average loss: 5.0594
# Iteration: 638; Percent complete: 16.0%; Average loss: 5.0606
# Iteration: 639; Percent complete: 16.0%; Average loss: 5.4585
# Iteration: 640; Percent complete: 16.0%; Average loss: 5.5234
# Iteration: 641; Percent complete: 16.0%; Average loss: 5.2889
# Iteration: 642; Percent complete: 16.1%; Average loss: 5.1530
# Iteration: 643; Percent complete: 16.1%; Average loss: 5.3748
# Iteration: 644; Percent complete: 16.1%; Average loss: 5.2556
# Iteration: 645; Percent complete: 16.1%; Average loss: 5.1621
# Iteration: 646; Percent complete: 16.2%; Average loss: 5.0628
# Iteration: 647; Percent complete: 16.2%; Average loss: 4.7949
# Iteration: 648; Percent complete: 16.2%; Average loss: 5.0834
# Iteration: 649; Percent complete: 16.2%; Average loss: 5.2006
# Iteration: 650; Percent complete: 16.2%; Average loss: 5.1076
# Iteration: 651; Percent complete: 16.3%; Average loss: 5.4234
# Iteration: 652; Percent complete: 16.3%; Average loss: 5.0471
# Iteration: 653; Percent complete: 16.3%; Average loss: 5.3268
# Iteration: 654; Percent complete: 16.4%; Average loss: 5.1709
# Iteration: 655; Percent complete: 16.4%; Average loss: 4.8829
# Iteration: 656; Percent complete: 16.4%; Average loss: 5.0601
# Iteration: 657; Percent complete: 16.4%; Average loss: 4.9037
# Iteration: 658; Percent complete: 16.4%; Average loss: 4.8710
# Iteration: 659; Percent complete: 16.5%; Average loss: 5.4983
# Iteration: 660; Percent complete: 16.5%; Average loss: 5.1040
# Iteration: 661; Percent complete: 16.5%; Average loss: 4.8717
# Iteration: 662; Percent complete: 16.6%; Average loss: 4.8330
# Iteration: 663; Percent complete: 16.6%; Average loss: 4.9451
# Iteration: 664; Percent complete: 16.6%; Average loss: 4.9050
# Iteration: 665; Percent complete: 16.6%; Average loss: 5.0120
# Iteration: 666; Percent complete: 16.7%; Average loss: 5.0640
# Iteration: 667; Percent complete: 16.7%; Average loss: 4.9816
# Iteration: 668; Percent complete: 16.7%; Average loss: 4.9396
# Iteration: 669; Percent complete: 16.7%; Average loss: 4.8815
# Iteration: 670; Percent complete: 16.8%; Average loss: 4.8791
# Iteration: 671; Percent complete: 16.8%; Average loss: 5.1462
# Iteration: 672; Percent complete: 16.8%; Average loss: 5.0673
# Iteration: 673; Percent complete: 16.8%; Average loss: 5.0386
# Iteration: 674; Percent complete: 16.9%; Average loss: 5.1195
# Iteration: 675; Percent complete: 16.9%; Average loss: 5.1671
# Iteration: 676; Percent complete: 16.9%; Average loss: 5.2094
# Iteration: 677; Percent complete: 16.9%; Average loss: 5.0799
# Iteration: 678; Percent complete: 17.0%; Average loss: 4.9325
# Iteration: 679; Percent complete: 17.0%; Average loss: 5.4159
# Iteration: 680; Percent complete: 17.0%; Average loss: 5.3178
# Iteration: 681; Percent complete: 17.0%; Average loss: 5.1169
# Iteration: 682; Percent complete: 17.1%; Average loss: 5.0122
# Iteration: 683; Percent complete: 17.1%; Average loss: 5.1085
# Iteration: 684; Percent complete: 17.1%; Average loss: 5.2117
# Iteration: 685; Percent complete: 17.1%; Average loss: 4.9034
# Iteration: 686; Percent complete: 17.2%; Average loss: 5.0413
# Iteration: 687; Percent complete: 17.2%; Average loss: 5.3627
# Iteration: 688; Percent complete: 17.2%; Average loss: 5.1289
# Iteration: 689; Percent complete: 17.2%; Average loss: 5.1768
# Iteration: 690; Percent complete: 17.2%; Average loss: 5.0199
# Iteration: 691; Percent complete: 17.3%; Average loss: 5.0277
# Iteration: 692; Percent complete: 17.3%; Average loss: 5.1521
# Iteration: 693; Percent complete: 17.3%; Average loss: 4.6540
# Iteration: 694; Percent complete: 17.3%; Average loss: 4.8919
# Iteration: 695; Percent complete: 17.4%; Average loss: 4.9969
# Iteration: 696; Percent complete: 17.4%; Average loss: 5.4152
# Iteration: 697; Percent complete: 17.4%; Average loss: 4.9211
# Iteration: 698; Percent complete: 17.4%; Average loss: 5.2717
# Iteration: 699; Percent complete: 17.5%; Average loss: 5.0113
# Iteration: 700; Percent complete: 17.5%; Average loss: 5.1885
# Iteration: 701; Percent complete: 17.5%; Average loss: 4.8351
# Iteration: 702; Percent complete: 17.5%; Average loss: 4.9594
# Iteration: 703; Percent complete: 17.6%; Average loss: 5.0175
# Iteration: 704; Percent complete: 17.6%; Average loss: 5.1354
# Iteration: 705; Percent complete: 17.6%; Average loss: 5.2171
# Iteration: 706; Percent complete: 17.6%; Average loss: 4.9237
# Iteration: 707; Percent complete: 17.7%; Average loss: 5.2477
# Iteration: 708; Percent complete: 17.7%; Average loss: 4.8978
# Iteration: 709; Percent complete: 17.7%; Average loss: 5.3288
# Iteration: 710; Percent complete: 17.8%; Average loss: 5.0701
# Iteration: 711; Percent complete: 17.8%; Average loss: 5.2172
# Iteration: 712; Percent complete: 17.8%; Average loss: 5.2289
# Iteration: 713; Percent complete: 17.8%; Average loss: 4.8501
# Iteration: 714; Percent complete: 17.8%; Average loss: 5.0944
# Iteration: 715; Percent complete: 17.9%; Average loss: 4.9923
# Iteration: 716; Percent complete: 17.9%; Average loss: 4.7891
# Iteration: 717; Percent complete: 17.9%; Average loss: 5.1868
# Iteration: 718; Percent complete: 17.9%; Average loss: 4.9175
# Iteration: 719; Percent complete: 18.0%; Average loss: 5.2296
# Iteration: 720; Percent complete: 18.0%; Average loss: 4.9913
# Iteration: 721; Percent complete: 18.0%; Average loss: 5.0944
# Iteration: 722; Percent complete: 18.1%; Average loss: 4.4695
# Iteration: 723; Percent complete: 18.1%; Average loss: 4.8040
# Iteration: 724; Percent complete: 18.1%; Average loss: 5.0940
# Iteration: 725; Percent complete: 18.1%; Average loss: 5.0139
# Iteration: 726; Percent complete: 18.1%; Average loss: 4.8328
# Iteration: 727; Percent complete: 18.2%; Average loss: 4.7015
# Iteration: 728; Percent complete: 18.2%; Average loss: 4.9624
# Iteration: 729; Percent complete: 18.2%; Average loss: 4.9185
# Iteration: 730; Percent complete: 18.2%; Average loss: 5.1468
# Iteration: 731; Percent complete: 18.3%; Average loss: 5.1202
# Iteration: 732; Percent complete: 18.3%; Average loss: 4.8891
# Iteration: 733; Percent complete: 18.3%; Average loss: 4.9724
# Iteration: 734; Percent complete: 18.4%; Average loss: 5.0823
# Iteration: 735; Percent complete: 18.4%; Average loss: 5.1623
# Iteration: 736; Percent complete: 18.4%; Average loss: 5.2997
# Iteration: 737; Percent complete: 18.4%; Average loss: 5.1553
# Iteration: 738; Percent complete: 18.4%; Average loss: 4.9702
# Iteration: 739; Percent complete: 18.5%; Average loss: 4.7853
# Iteration: 740; Percent complete: 18.5%; Average loss: 4.9390
# Iteration: 741; Percent complete: 18.5%; Average loss: 4.9722
# Iteration: 742; Percent complete: 18.6%; Average loss: 4.8584
# Iteration: 743; Percent complete: 18.6%; Average loss: 5.1693
# Iteration: 744; Percent complete: 18.6%; Average loss: 5.2012
# Iteration: 745; Percent complete: 18.6%; Average loss: 5.1648
# Iteration: 746; Percent complete: 18.6%; Average loss: 5.1107
# Iteration: 747; Percent complete: 18.7%; Average loss: 4.9138
# Iteration: 748; Percent complete: 18.7%; Average loss: 4.6416
# Iteration: 749; Percent complete: 18.7%; Average loss: 5.0476
# Iteration: 750; Percent complete: 18.8%; Average loss: 4.9944
# Iteration: 751; Percent complete: 18.8%; Average loss: 4.6538
# Iteration: 752; Percent complete: 18.8%; Average loss: 5.0119
# Iteration: 753; Percent complete: 18.8%; Average loss: 5.3064
# Iteration: 754; Percent complete: 18.9%; Average loss: 5.0742
# Iteration: 755; Percent complete: 18.9%; Average loss: 5.0219
# Iteration: 756; Percent complete: 18.9%; Average loss: 5.1907
# Iteration: 757; Percent complete: 18.9%; Average loss: 5.1377
# Iteration: 758; Percent complete: 18.9%; Average loss: 4.9243
# Iteration: 759; Percent complete: 19.0%; Average loss: 4.9652
# Iteration: 760; Percent complete: 19.0%; Average loss: 5.1727
# Iteration: 761; Percent complete: 19.0%; Average loss: 5.0401
# Iteration: 762; Percent complete: 19.1%; Average loss: 5.3300
# Iteration: 763; Percent complete: 19.1%; Average loss: 4.9707
# Iteration: 764; Percent complete: 19.1%; Average loss: 5.2146
# Iteration: 765; Percent complete: 19.1%; Average loss: 5.1793
# Iteration: 766; Percent complete: 19.1%; Average loss: 4.7503
# Iteration: 767; Percent complete: 19.2%; Average loss: 5.0015
# Iteration: 768; Percent complete: 19.2%; Average loss: 4.8236
# Iteration: 769; Percent complete: 19.2%; Average loss: 4.6938
# Iteration: 770; Percent complete: 19.2%; Average loss: 5.1500
# Iteration: 771; Percent complete: 19.3%; Average loss: 4.8394
# Iteration: 772; Percent complete: 19.3%; Average loss: 5.0405
# Iteration: 773; Percent complete: 19.3%; Average loss: 4.9969
# Iteration: 774; Percent complete: 19.4%; Average loss: 5.0712
# Iteration: 775; Percent complete: 19.4%; Average loss: 4.9853
# Iteration: 776; Percent complete: 19.4%; Average loss: 4.9622
# Iteration: 777; Percent complete: 19.4%; Average loss: 5.0361
# Iteration: 778; Percent complete: 19.4%; Average loss: 4.4566
# Iteration: 779; Percent complete: 19.5%; Average loss: 5.2823
# Iteration: 780; Percent complete: 19.5%; Average loss: 5.0481
# Iteration: 781; Percent complete: 19.5%; Average loss: 4.7103
# ...
# Iteration: 3748; Percent complete: 93.7%; Average loss: 4.3520
# Iteration: 3749; Percent complete: 93.7%; Average loss: 3.9911
# Iteration: 3750; Percent complete: 93.8%; Average loss: 4.1726
# Iteration: 3751; Percent complete: 93.8%; Average loss: 4.3478
# Iteration: 3752; Percent complete: 93.8%; Average loss: 4.2629
# Iteration: 3753; Percent complete: 93.8%; Average loss: 4.2571
# Iteration: 3754; Percent complete: 93.8%; Average loss: 4.0092
# Iteration: 3755; Percent complete: 93.9%; Average loss: 4.0518
# Iteration: 3756; Percent complete: 93.9%; Average loss: 3.8649
# Iteration: 3757; Percent complete: 93.9%; Average loss: 4.1950
# Iteration: 3758; Percent complete: 94.0%; Average loss: 4.1185
# Iteration: 3759; Percent complete: 94.0%; Average loss: 4.1814
# Iteration: 3760; Percent complete: 94.0%; Average loss: 4.2792
# Iteration: 3761; Percent complete: 94.0%; Average loss: 4.2508
# Iteration: 3762; Percent complete: 94.0%; Average loss: 4.0764
# Iteration: 3763; Percent complete: 94.1%; Average loss: 4.0573
# Iteration: 3764; Percent complete: 94.1%; Average loss: 4.2426
# Iteration: 3765; Percent complete: 94.1%; Average loss: 4.0981
# Iteration: 3766; Percent complete: 94.2%; Average loss: 4.1981
# Iteration: 3767; Percent complete: 94.2%; Average loss: 4.3680
# Iteration: 3768; Percent complete: 94.2%; Average loss: 4.2720
# Iteration: 3769; Percent complete: 94.2%; Average loss: 4.2099
# Iteration: 3770; Percent complete: 94.2%; Average loss: 4.1647
# Iteration: 3771; Percent complete: 94.3%; Average loss: 3.9274
# Iteration: 3772; Percent complete: 94.3%; Average loss: 4.0567
# Iteration: 3773; Percent complete: 94.3%; Average loss: 3.8461
# Iteration: 3774; Percent complete: 94.3%; Average loss: 4.2840
# Iteration: 3775; Percent complete: 94.4%; Average loss: 4.1622
# Iteration: 3776; Percent complete: 94.4%; Average loss: 3.9432
# Iteration: 3777; Percent complete: 94.4%; Average loss: 4.5159
# Iteration: 3778; Percent complete: 94.5%; Average loss: 4.1845
# Iteration: 3779; Percent complete: 94.5%; Average loss: 4.5347
# Iteration: 3780; Percent complete: 94.5%; Average loss: 4.0737
# Iteration: 3781; Percent complete: 94.5%; Average loss: 4.3773
# Iteration: 3782; Percent complete: 94.5%; Average loss: 4.3943
# Iteration: 3783; Percent complete: 94.6%; Average loss: 4.2888
# Iteration: 3784; Percent complete: 94.6%; Average loss: 3.9561
# Iteration: 3785; Percent complete: 94.6%; Average loss: 3.9780
# Iteration: 3786; Percent complete: 94.7%; Average loss: 4.4459
# Iteration: 3787; Percent complete: 94.7%; Average loss: 4.3364
# Iteration: 3788; Percent complete: 94.7%; Average loss: 4.1243
# Iteration: 3789; Percent complete: 94.7%; Average loss: 4.0953
# Iteration: 3790; Percent complete: 94.8%; Average loss: 4.0277
# Iteration: 3791; Percent complete: 94.8%; Average loss: 4.3934
# Iteration: 3792; Percent complete: 94.8%; Average loss: 4.2232
# Iteration: 3793; Percent complete: 94.8%; Average loss: 4.2652
# Iteration: 3794; Percent complete: 94.8%; Average loss: 4.2165
# Iteration: 3795; Percent complete: 94.9%; Average loss: 4.3193
# Iteration: 3796; Percent complete: 94.9%; Average loss: 4.1476
# Iteration: 3797; Percent complete: 94.9%; Average loss: 4.1418
# Iteration: 3798; Percent complete: 95.0%; Average loss: 4.2177
# Iteration: 3799; Percent complete: 95.0%; Average loss: 4.0368
# Iteration: 3800; Percent complete: 95.0%; Average loss: 4.2629
# Iteration: 3801; Percent complete: 95.0%; Average loss: 4.1934
# Iteration: 3802; Percent complete: 95.0%; Average loss: 4.1820
# Iteration: 3803; Percent complete: 95.1%; Average loss: 4.2072
# Iteration: 3804; Percent complete: 95.1%; Average loss: 4.2111
# Iteration: 3805; Percent complete: 95.1%; Average loss: 4.1877
# Iteration: 3806; Percent complete: 95.2%; Average loss: 4.4368
# Iteration: 3807; Percent complete: 95.2%; Average loss: 3.9250
# Iteration: 3808; Percent complete: 95.2%; Average loss: 3.9017
# Iteration: 3809; Percent complete: 95.2%; Average loss: 4.1878
# Iteration: 3810; Percent complete: 95.2%; Average loss: 4.0881
# Iteration: 3811; Percent complete: 95.3%; Average loss: 3.8683
# Iteration: 3812; Percent complete: 95.3%; Average loss: 4.3728
# Iteration: 3813; Percent complete: 95.3%; Average loss: 4.0763
# Iteration: 3814; Percent complete: 95.3%; Average loss: 3.8443
# Iteration: 3815; Percent complete: 95.4%; Average loss: 4.3320
# Iteration: 3816; Percent complete: 95.4%; Average loss: 4.2435
# Iteration: 3817; Percent complete: 95.4%; Average loss: 4.1011
# Iteration: 3818; Percent complete: 95.5%; Average loss: 3.9411
# Iteration: 3819; Percent complete: 95.5%; Average loss: 3.9016
# Iteration: 3820; Percent complete: 95.5%; Average loss: 4.2490
# Iteration: 3821; Percent complete: 95.5%; Average loss: 4.3160
# Iteration: 3822; Percent complete: 95.5%; Average loss: 4.1492
# Iteration: 3823; Percent complete: 95.6%; Average loss: 4.1778
# Iteration: 3824; Percent complete: 95.6%; Average loss: 3.7974
# Iteration: 3825; Percent complete: 95.6%; Average loss: 4.0041
# Iteration: 3826; Percent complete: 95.7%; Average loss: 3.9504
# Iteration: 3827; Percent complete: 95.7%; Average loss: 3.9085
# Iteration: 3828; Percent complete: 95.7%; Average loss: 4.1483
# Iteration: 3829; Percent complete: 95.7%; Average loss: 3.7402
# Iteration: 3830; Percent complete: 95.8%; Average loss: 4.1071
# Iteration: 3831; Percent complete: 95.8%; Average loss: 4.1532
# Iteration: 3832; Percent complete: 95.8%; Average loss: 3.9075
# Iteration: 3833; Percent complete: 95.8%; Average loss: 4.1746
# Iteration: 3834; Percent complete: 95.9%; Average loss: 4.2232
# Iteration: 3835; Percent complete: 95.9%; Average loss: 3.9932
# Iteration: 3836; Percent complete: 95.9%; Average loss: 4.2634
# Iteration: 3837; Percent complete: 95.9%; Average loss: 4.3159
# Iteration: 3838; Percent complete: 96.0%; Average loss: 4.4266
# Iteration: 3839; Percent complete: 96.0%; Average loss: 4.2051
# Iteration: 3840; Percent complete: 96.0%; Average loss: 4.0177
# Iteration: 3841; Percent complete: 96.0%; Average loss: 3.9765
# Iteration: 3842; Percent complete: 96.0%; Average loss: 4.1609
# Iteration: 3843; Percent complete: 96.1%; Average loss: 3.7415
# Iteration: 3844; Percent complete: 96.1%; Average loss: 4.2653
# Iteration: 3845; Percent complete: 96.1%; Average loss: 3.8228
# Iteration: 3846; Percent complete: 96.2%; Average loss: 4.2079
# Iteration: 3847; Percent complete: 96.2%; Average loss: 3.8914
# Iteration: 3848; Percent complete: 96.2%; Average loss: 4.3559
# Iteration: 3849; Percent complete: 96.2%; Average loss: 4.2391
# Iteration: 3850; Percent complete: 96.2%; Average loss: 3.9672
# Iteration: 3851; Percent complete: 96.3%; Average loss: 4.1250
# Iteration: 3852; Percent complete: 96.3%; Average loss: 4.4042
# Iteration: 3853; Percent complete: 96.3%; Average loss: 4.0766
# Iteration: 3854; Percent complete: 96.4%; Average loss: 4.0969
# Iteration: 3855; Percent complete: 96.4%; Average loss: 4.0649
# Iteration: 3856; Percent complete: 96.4%; Average loss: 3.9749
# Iteration: 3857; Percent complete: 96.4%; Average loss: 4.1612
# Iteration: 3858; Percent complete: 96.5%; Average loss: 3.7803
# Iteration: 3859; Percent complete: 96.5%; Average loss: 4.0327
# Iteration: 3860; Percent complete: 96.5%; Average loss: 4.3223
# Iteration: 3861; Percent complete: 96.5%; Average loss: 4.1433
# Iteration: 3862; Percent complete: 96.5%; Average loss: 3.9888
# Iteration: 3863; Percent complete: 96.6%; Average loss: 4.1021
# Iteration: 3864; Percent complete: 96.6%; Average loss: 4.0337
# Iteration: 3865; Percent complete: 96.6%; Average loss: 4.1444
# Iteration: 3866; Percent complete: 96.7%; Average loss: 3.8807
# Iteration: 3867; Percent complete: 96.7%; Average loss: 4.4200
# Iteration: 3868; Percent complete: 96.7%; Average loss: 4.1490
# Iteration: 3869; Percent complete: 96.7%; Average loss: 4.3869
# Iteration: 3870; Percent complete: 96.8%; Average loss: 4.3083
# Iteration: 3871; Percent complete: 96.8%; Average loss: 4.1180
# Iteration: 3872; Percent complete: 96.8%; Average loss: 4.0048
# Iteration: 3873; Percent complete: 96.8%; Average loss: 4.3697
# Iteration: 3874; Percent complete: 96.9%; Average loss: 4.0069
# Iteration: 3875; Percent complete: 96.9%; Average loss: 3.8890
# Iteration: 3876; Percent complete: 96.9%; Average loss: 4.4784
# Iteration: 3877; Percent complete: 96.9%; Average loss: 4.2271
# Iteration: 3878; Percent complete: 97.0%; Average loss: 4.2789
# Iteration: 3879; Percent complete: 97.0%; Average loss: 4.2204
# Iteration: 3880; Percent complete: 97.0%; Average loss: 4.0445
# Iteration: 3881; Percent complete: 97.0%; Average loss: 4.3012
# Iteration: 3882; Percent complete: 97.0%; Average loss: 3.9444
# Iteration: 3883; Percent complete: 97.1%; Average loss: 4.3260
# Iteration: 3884; Percent complete: 97.1%; Average loss: 4.2737
# Iteration: 3885; Percent complete: 97.1%; Average loss: 4.0562
# Iteration: 3886; Percent complete: 97.2%; Average loss: 4.1327
# Iteration: 3887; Percent complete: 97.2%; Average loss: 4.1657
# Iteration: 3888; Percent complete: 97.2%; Average loss: 4.1626
# Iteration: 3889; Percent complete: 97.2%; Average loss: 4.1164
# Iteration: 3890; Percent complete: 97.2%; Average loss: 4.3798
# Iteration: 3891; Percent complete: 97.3%; Average loss: 4.0058
# Iteration: 3892; Percent complete: 97.3%; Average loss: 4.2913
# Iteration: 3893; Percent complete: 97.3%; Average loss: 4.4606
# Iteration: 3894; Percent complete: 97.4%; Average loss: 4.3388
# Iteration: 3895; Percent complete: 97.4%; Average loss: 4.1753
# Iteration: 3896; Percent complete: 97.4%; Average loss: 3.9697
# Iteration: 3897; Percent complete: 97.4%; Average loss: 4.2279
# Iteration: 3898; Percent complete: 97.5%; Average loss: 3.8739
# Iteration: 3899; Percent complete: 97.5%; Average loss: 4.1421
# Iteration: 3900; Percent complete: 97.5%; Average loss: 4.1483
# Iteration: 3901; Percent complete: 97.5%; Average loss: 3.9802
# Iteration: 3902; Percent complete: 97.5%; Average loss: 4.3204
# Iteration: 3903; Percent complete: 97.6%; Average loss: 3.9063
# Iteration: 3904; Percent complete: 97.6%; Average loss: 4.1703
# Iteration: 3905; Percent complete: 97.6%; Average loss: 4.3826
# Iteration: 3906; Percent complete: 97.7%; Average loss: 4.2740
# Iteration: 3907; Percent complete: 97.7%; Average loss: 3.9253
# Iteration: 3908; Percent complete: 97.7%; Average loss: 3.8961
# Iteration: 3909; Percent complete: 97.7%; Average loss: 4.3867
# Iteration: 3910; Percent complete: 97.8%; Average loss: 3.9884
# Iteration: 3911; Percent complete: 97.8%; Average loss: 4.3289
# Iteration: 3912; Percent complete: 97.8%; Average loss: 3.8757
# Iteration: 3913; Percent complete: 97.8%; Average loss: 4.3741
# Iteration: 3914; Percent complete: 97.9%; Average loss: 4.3115
# Iteration: 3915; Percent complete: 97.9%; Average loss: 4.0142
# Iteration: 3916; Percent complete: 97.9%; Average loss: 4.2911
# Iteration: 3917; Percent complete: 97.9%; Average loss: 3.8134
# Iteration: 3918; Percent complete: 98.0%; Average loss: 4.2974
# Iteration: 3919; Percent complete: 98.0%; Average loss: 4.0953
# Iteration: 3920; Percent complete: 98.0%; Average loss: 4.1356
# Iteration: 3921; Percent complete: 98.0%; Average loss: 4.0484
# Iteration: 3922; Percent complete: 98.0%; Average loss: 4.0478
# Iteration: 3923; Percent complete: 98.1%; Average loss: 3.8101
# Iteration: 3924; Percent complete: 98.1%; Average loss: 4.3161
# Iteration: 3925; Percent complete: 98.1%; Average loss: 4.1460
# Iteration: 3926; Percent complete: 98.2%; Average loss: 4.3645
# Iteration: 3927; Percent complete: 98.2%; Average loss: 4.0530
# Iteration: 3928; Percent complete: 98.2%; Average loss: 4.0230
# Iteration: 3929; Percent complete: 98.2%; Average loss: 3.7823
# Iteration: 3930; Percent complete: 98.2%; Average loss: 4.1846
# Iteration: 3931; Percent complete: 98.3%; Average loss: 4.0549
# Iteration: 3932; Percent complete: 98.3%; Average loss: 4.1236
# Iteration: 3933; Percent complete: 98.3%; Average loss: 4.1918
# Iteration: 3934; Percent complete: 98.4%; Average loss: 4.3241
# Iteration: 3935; Percent complete: 98.4%; Average loss: 3.9904
# Iteration: 3936; Percent complete: 98.4%; Average loss: 4.2408
# Iteration: 3937; Percent complete: 98.4%; Average loss: 4.1936
# Iteration: 3938; Percent complete: 98.5%; Average loss: 4.1174
# Iteration: 3939; Percent complete: 98.5%; Average loss: 3.8680
# Iteration: 3940; Percent complete: 98.5%; Average loss: 4.0516
# Iteration: 3941; Percent complete: 98.5%; Average loss: 4.1834
# Iteration: 3942; Percent complete: 98.6%; Average loss: 4.4524
# Iteration: 3943; Percent complete: 98.6%; Average loss: 4.0429
# Iteration: 3944; Percent complete: 98.6%; Average loss: 4.2766
# Iteration: 3945; Percent complete: 98.6%; Average loss: 4.1523
# Iteration: 3946; Percent complete: 98.7%; Average loss: 4.2374
# Iteration: 3947; Percent complete: 98.7%; Average loss: 4.0454
# Iteration: 3948; Percent complete: 98.7%; Average loss: 4.0517
# Iteration: 3949; Percent complete: 98.7%; Average loss: 3.8576
# Iteration: 3950; Percent complete: 98.8%; Average loss: 3.9017
# Iteration: 3951; Percent complete: 98.8%; Average loss: 4.1160
# Iteration: 3952; Percent complete: 98.8%; Average loss: 4.0373
# Iteration: 3953; Percent complete: 98.8%; Average loss: 4.0904
# Iteration: 3954; Percent complete: 98.9%; Average loss: 3.8599
# Iteration: 3955; Percent complete: 98.9%; Average loss: 3.9716
# Iteration: 3956; Percent complete: 98.9%; Average loss: 3.9718
# Iteration: 3957; Percent complete: 98.9%; Average loss: 3.9120
# Iteration: 3958; Percent complete: 99.0%; Average loss: 4.0721
# Iteration: 3959; Percent complete: 99.0%; Average loss: 4.1726
# Iteration: 3960; Percent complete: 99.0%; Average loss: 3.9318
# Iteration: 3961; Percent complete: 99.0%; Average loss: 4.1598
# Iteration: 3962; Percent complete: 99.1%; Average loss: 4.2499
# Iteration: 3963; Percent complete: 99.1%; Average loss: 4.2586
# Iteration: 3964; Percent complete: 99.1%; Average loss: 4.0389
# Iteration: 3965; Percent complete: 99.1%; Average loss: 3.9274
# Iteration: 3966; Percent complete: 99.2%; Average loss: 4.3095
# Iteration: 3967; Percent complete: 99.2%; Average loss: 4.1852
# Iteration: 3968; Percent complete: 99.2%; Average loss: 4.0967
# Iteration: 3969; Percent complete: 99.2%; Average loss: 4.0016
# Iteration: 3970; Percent complete: 99.2%; Average loss: 4.1461
# Iteration: 3971; Percent complete: 99.3%; Average loss: 4.1020
# Iteration: 3972; Percent complete: 99.3%; Average loss: 3.8433
# Iteration: 3973; Percent complete: 99.3%; Average loss: 3.9990
# Iteration: 3974; Percent complete: 99.4%; Average loss: 4.4820
# Iteration: 3975; Percent complete: 99.4%; Average loss: 3.8244
# Iteration: 3976; Percent complete: 99.4%; Average loss: 4.0762
# Iteration: 3977; Percent complete: 99.4%; Average loss: 4.2664
# Iteration: 3978; Percent complete: 99.5%; Average loss: 4.0559
# Iteration: 3979; Percent complete: 99.5%; Average loss: 4.1484
# Iteration: 3980; Percent complete: 99.5%; Average loss: 4.1948
# Iteration: 3981; Percent complete: 99.5%; Average loss: 3.9313
# Iteration: 3982; Percent complete: 99.6%; Average loss: 4.1871
# Iteration: 3983; Percent complete: 99.6%; Average loss: 4.1047
# Iteration: 3984; Percent complete: 99.6%; Average loss: 3.6914
# Iteration: 3985; Percent complete: 99.6%; Average loss: 4.3152
# Iteration: 3986; Percent complete: 99.7%; Average loss: 3.9646
# Iteration: 3987; Percent complete: 99.7%; Average loss: 4.2108
# Iteration: 3988; Percent complete: 99.7%; Average loss: 4.0646
# Iteration: 3989; Percent complete: 99.7%; Average loss: 3.9612
# Iteration: 3990; Percent complete: 99.8%; Average loss: 4.2048
# Iteration: 3991; Percent complete: 99.8%; Average loss: 4.2684
# Iteration: 3992; Percent complete: 99.8%; Average loss: 4.2603
# Iteration: 3993; Percent complete: 99.8%; Average loss: 3.9626
# Iteration: 3994; Percent complete: 99.9%; Average loss: 4.0920
# Iteration: 3995; Percent complete: 99.9%; Average loss: 4.4368
# Iteration: 3996; Percent complete: 99.9%; Average loss: 3.9827
# Iteration: 3997; Percent complete: 99.9%; Average loss: 4.0530
# Iteration: 3998; Percent complete: 100.0%; Average loss: 4.2511
# Iteration: 3999; Percent complete: 100.0%; Average loss: 4.3237
# Iteration: 4000; Percent complete: 100.0%; Average loss: 4.0459

# %%
# Set dropout layers to ``eval`` mode
encoder.eval()
decoder.eval()

# Initialize search module
searcher = GreedySearchDecoder(encoder, decoder)

# %%
evaluateInput(encoder, decoder, searcher, voc)
# Out:
# > hello
# Bot: hi ? ? ? ? ? ? ? ? ?
# > how are you?
# Bot: what are you seeing ? ? ? ? ? ? ? ?
# > what is the latest version of ubuntu?
# Bot: it s a release version of ubuntu . . . ? ? ?
# > what is your name?
# Bot: what s the problem ? ? ? ? ? ? ? ?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-4e20b9561b77> in <cell line: 1>()
# ----> 1 evaluateInput(encoder, decoder, searcher, voc)
#
# <ipython-input-21-7cdfa7345e53> in evaluateInput(encoder, decoder, searcher, voc)
#      22         try:
#      23             # Get input sentence
# ---> 24             input_sentence = input('> ')
#      25             # Check if it is quit case
#      26             if input_sentence == 'q' or input_sentence == 'quit': break
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
